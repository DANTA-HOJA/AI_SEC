# %% [markdown]
# # Initialize PyImageJ

# %%
# Import module
import jpype
# Enable Java imports
import jpype.imports
# Pull in types
from jpype.types import *

import scyjava as sj # scyjava : Supercharged Java access from Python, see https://github.com/scijava/scyjava
import imagej

# Configurations
# NOTE: The ImageJ2 gateway is initialized through a Java Virtual Machine (JVM). If you want to configure the JVM, it must be done before initializing an ImageJ2 gateway.
# sj.config.add_option('-Xmx10g') # adjust memory available to Java
sj.config.endpoints.append('ome:formats-gpl:6.11.1')

# %%
Fiji_Local = r"C:\Users\confocal_microscope\Desktop\Tools\Fiji.app"

# ij = imagej.init(Fiji_Local) # Same as "ij = imagej.init(Fiji_Local, mode='headless')", PyImageJ’s default mode is headless
# ij = imagej.init(Fiji_Local, mode='gui') # GUI mode (會卡在這一行 -> blocking), for more explainations : https://pyimagej.readthedocs.io/en/latest/Initialization.html#gui-mode
ij = imagej.init(Fiji_Local, mode='interactive') # Interactive mode (可以繼續向下執行 -> non-blocking), for more explainations : https://pyimagej.readthedocs.io/en/latest/Initialization.html#interactive-mode
ij.ui().showUI() # display the Fiji GUI

print(ij.getApp().getInfo(True)) # ImageJ2 2.9.0/1.53t
# Out:
# ImageJ2 2.9.0/1.54b; Java 1.8.0_362 [amd64]; 188MB of 14542MB

# %%
def dump_info(image, CLI_print_title:str=None):
    """A handy function to print details of an image object."""
    name = image.name if hasattr(image, 'name') else None # xarray
    if name is None and hasattr(image, 'getName'): name = image.getName() # Dataset
    if name is None and hasattr(image, 'getTitle'): name = image.getTitle() # ImagePlus
    
    if CLI_print_title is not None: print(f"--> {CLI_print_title}:\n")
    print(f"    name  : {name or 'N/A'}")
    print(f"    type  : {type(image)}")
    print(f"    dtype : {image.dtype if hasattr(image, 'dtype') else 'N/A'}")
    print(f"    shape : {image.shape if hasattr(image, 'shape') else 'N/A'}")
    print(f"    dims  : {image.dims if hasattr(image, 'dims') else 'N/A'}\n")

# %% [markdown]
# Get ```seriesCount``` ( Method 1 )

# %%
loci = jpype.JPackage("loci")
loci.common.DebugTools.setRootLevel("ERROR")
Ext = loci.plugins.macro.LociFunctions()

# LociFunctions = sj.jimport("loci.plugins.macro.LociFunctions")
# Ext = LociFunctions()

test_lif = r"C:\Users\confocal_microscope\Desktop\PyImageJ-test-data\BrightField_RAW\20220610_CE001_palmskin_8dpf.lif"

Ext.setId(test_lif)

seriesCount = jpype.java.lang.Double[1]
print(f'seriesCount {type(seriesCount)}: {seriesCount}')
Ext.getSeriesCount(seriesCount)
print(f'seriesCount {type(seriesCount)}: {seriesCount}')

seriesCount = seriesCount[0]
print(f'seriesCount {type(seriesCount)}: {seriesCount}')
Ext.close()
# Out:
# seriesCount <java class 'java.lang.Double[]'>: [None]
# seriesCount <java class 'java.lang.Double[]'>: [6.0]
# seriesCount <java class 'java.lang.Double'>: 6.0

# %% [markdown]
# Get ```seriesCount``` ( Method 2 )

# %%
loci = jpype.JPackage("loci")
loci.common.DebugTools.setRootLevel("ERROR")
Reader = loci.formats.ImageReader()

# ImageReader = sj.jimport("loci.formats.ImageReader")
# Reader = ImageReader()

test_lif = r"C:\Users\confocal_microscope\Desktop\PyImageJ-test-data\BrightField_RAW\20220610_CE001_palmskin_8dpf.lif"

Reader.setId(test_lif)

seriesCount = Reader.getSeriesCount()
print(f'seriesCount {type(seriesCount)}: {seriesCount}')
# Out:
# seriesCount <java class 'JInt'>: 6

# %% [markdown]
# # Start Process

# %% [markdown]
# Original file is ```20220614 macro for SL and SA measurement_by KY.ijm```
#
# Modify by following :
# - using pyimagej
# - bug fix
# - add **```WARNING```** and **```ERROR```** remind
# - make log file pretty
# - see more in [report](/report/report.md#20230126)

# %%
import os
import re
import logging
from glob import glob
from tqdm.auto import tqdm

import  numpy as np

log: logging.Logger = logging.getLogger(name=r'{Test}_BF_analysis')
log.setLevel(logging.DEBUG)
formatter: logging.Formatter = logging.Formatter('| %(asctime)s | %(name)s | %(levelname)s | %(message)s')

stream_handler: logging.StreamHandler = logging.StreamHandler()
stream_handler.setFormatter(formatter)
log.addHandler(stream_handler)


def create_new_dir(path:str, end="\n", display_in_CLI=True, use_tqdm=False):
    if not os.path.exists(path):
        # if the demo_folder directory is not exist then create it.
        os.makedirs(path)
        if use_tqdm: tqdm.write(f"path: '{path}' is created!{end}")
        elif display_in_CLI: print(f"path: '{path}' is created!{end}")

# %%
loci = jpype.JPackage("loci")
loci.common.DebugTools.setRootLevel("ERROR")
Reader = loci.formats.ImageReader()

# Important!!!
from ij.plugin.frame import RoiManager
from ij.plugin import ImageCalculator
rm = RoiManager()
imageCalculator = ImageCalculator()


# File Input
bf_raw_lif_source = r"C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW"

# Result Output
ap_data = r"C:\Users\confocal_microscope\Desktop\{PyIJ_OutTest}_BF_Analysis" # r"C:\Users\confocal_microscope\Desktop\WorkingDir\(D2)_Image_AP\{Data}_Data\{20221209_UPDATE_82}_Academia_Sinica_i324"
analysis_method_desc = "KY"
analysis_root = os.path.join(ap_data, f"{{{analysis_method_desc}}}_BF_Analysis")


# Create sub folder
dir_tiff = os.path.join(analysis_root, "TIFF")
dir_metaimg = os.path.join(analysis_root, "MetaImage")
dir_result = os.path.join(analysis_root, "Result")
create_new_dir(dir_tiff, display_in_CLI=False)
create_new_dir(dir_metaimg, display_in_CLI=False)
create_new_dir(dir_result, display_in_CLI=False)


# Scan Leica LIF file
lif_path_list  = glob(os.path.normpath(f"{bf_raw_lif_source}/*/*.lif"))
log.info(f'lif_path_list {type(lif_path_list)}: {lif_path_list}, [ found {len(lif_path_list)} files ] \n')


# Create log writer
log_path = os.path.join(analysis_root, "Logs.log")
log_writer = open(log_path, mode="w")



fish_id = 0
for i, lif_path in enumerate(lif_path_list):
    
    log.info(f"Processing ... {i+1}/{len(lif_path_list)}")
    
    Reader.setId(lif_path)
    log.info(f'LIF_FILE : {lif_path}')
    
    seriesCount = Reader.getSeriesCount()
    log.info(f'seriesCount : {seriesCount}')
    
    # Write Log
    log_writer.write("\n\n\n")
    log_writer.write(f"|-----------------------------------------  Processing ... {i+1}/{len(lif_path_list)}  ----------------------------------------- \n")
    log_writer.write(f"| \n")
    log_writer.write(f"|         LIF_FILE : {lif_path.split(os.sep)[-1]} \n")
    log_writer.write(f"| \n")


    for j in range(seriesCount):
        
        ij.IJ.run("Bio-Formats Importer", f"open='{lif_path}' color_mode=Default rois_import=[ROI manager] view=Hyperstack stack_order=XYCZT series_{j+1}")
        img = ij.WindowManager.getCurrentImage() # get image, <java class 'ij.ImagePlus'>
        # dump_info(img)
        # img.show()
        img.hide()
        
        
        # Get names and image dimensions
        # Consociate "BrightField_RAW" file_name
        file_name = lif_path.split(os.sep)[-1].split(".")[0]
        file_name_list = re.split(" |_|-", file_name)
        assert len(file_name_list) == 4, f"file_name format error, current : '{file_name}', expect like : '20221125_AI005_palmskin_10dpf.lif'"
        file_name = "_".join(file_name_list)
        # Consociate Prop("Image name")
        image_name = img.getProp("Image name")
        image_name_list = re.split(" |_|-", str(image_name))
        image_name = "_".join(image_name_list)
        # Combine 2 names above
        seN = f"{file_name} - {image_name}"
        img_dimensions = img.getDimensions()
        log.info(f"series {j+1:{len(str(seriesCount))}}/{seriesCount} : '{seN}' , Dimensions : {img_dimensions} ( width, height, channels, slices, frames )")
        # Write Log
        log_writer.write(f"|-- processing ...  series {j+1:{len(str(seriesCount))}}/{seriesCount} in {i+1}/{len(lif_path_list)} \n")
        log_writer.write(f"|         {seN} \n")
        log_writer.write(f"|         Dimensions : {img_dimensions} ( width, height, channels, slices, frames ) \n")
        
        
        # Get fish_id and create subfolder in "--MetaImage" by fish_id
        seN_split = re.split("[fish _-]", seN)
        while "" in seN_split: seN_split.remove("")
        if (fish_id == seN_split[9]):
            log.info("      #### WARNING : Detect ' fish_id ' is same as previous processed fish --> skip this image"); # WARNING:
            # Write Log
            log_writer.write("| #### WARNING : Detect ' fish_id ' is same as previous processed fish --> skip this image \n") # WARNING:
            log_writer.write("| \n")
            continue
        else:
            fish_id = seN_split[9]
            # log.info(fish_id)
        # metaimg_subfolder = os.path.join(dir_metaimg, f"Fish_{fish_id}")
        metaimg_subfolder = os.path.join(dir_metaimg, seN)
        create_new_dir(metaimg_subfolder, display_in_CLI=False)
        
        
        
        slices = img_dimensions[3]
        if slices > 0:
            
            # Find focused slices
        
            #   Pick up focused slice if slices > 1
            #   Plugin ref : https://sites.google.com/site/qingzongtseng/find-focus
            #   Algorithm  : autofocus algorithm "Normalized variance"  (Groen et al., 1985; Yeo et al., 1993).
            if slices > 1:
                log.info("      #### WARNING : Number of Slices > 1, run ' Find focused slices ' ") # WARNING:
                # Write Log
                log_writer.write("| #### WARNING : Number of Slices > 1, run ' Find focused slices ' \n") # WARNING:
                ij.IJ.run(img, "Find focused slices", "select=100 variance=0.000 select_only")
                img = ij.WindowManager.getCurrentImage()
                # img.show()
                img.hide()
            # dump_info(img)
            ij.IJ.saveAsTiff(img, os.path.normpath(f"{dir_tiff}/{seN}.tif"))
            # ij.IJ.saveAs(img, "Tiff", os.path.normpath(f"{dir_tiff}/{seN}.tif"))
            # img.show()
            img.hide()


            # Convert to 8-bit and Set Scale

            ij.IJ.run("Conversions...", "scale weighted")
            ij.IJ.run(img, "8-bit", "")
            # img.show()
            img.hide()
            
            # Consociate the unit ( relationship between micron and pixel )
            #   To prevent some series of images are in different scales, for example, "20220708_CE009_palmskin_8dpf.lif"
			#   Microscope Metadata : 1 pixel = 0.0000065 m = 6.5 micron
            ij.IJ.run(img, "Set Scale...", "distance=0.3076923076923077 known=1 unit=micron")
            # img.show()
            img.hide()

        
            # Cropping image
        
            img.setRoi(50, 700, 1950, 700)
            crop_img = img.crop()
            ij.IJ.saveAsTiff(crop_img, os.path.normpath(f"{metaimg_subfolder}/{seN}_Cropped.tif"))
            # crop_img.show()
            crop_img.hide()


            # Threshold
            
            crop_img_threshold = crop_img.duplicate()
            ij.IJ.run(crop_img_threshold, "Auto Threshold", "method=Triangle white")
            ij.prefs.blackBackground = True
            ij.IJ.run(crop_img_threshold, "Convert to Mask", "")
            ij.IJ.saveAsTiff(crop_img_threshold, os.path.normpath(f"{metaimg_subfolder}/{seN}_Threshold.tif"))
            # crop_img_threshold.show()
            crop_img_threshold.hide()
            
            
            # SL and SA measurement
            
            ij.IJ.run("Set Measurements...", "area feret's display redirect=None decimal=2")
            ij.IJ.run(crop_img_threshold, "Analyze Particles...", "size=800000-4000000 show=Masks display include add")
            mask_img = ij.WindowManager.getCurrentImage()
            ij.IJ.run(mask_img, "Convert to Mask", "")
            ij.IJ.saveAsTiff(mask_img, os.path.normpath(f"{metaimg_subfolder}/{seN}--Mask.tif"))
            # mask_img.show()
            mask_img.hide()
            
            rm.runCommand("Show All with labels")
            rm_size = int(rm.getCount())
            if rm_size == 1:  # success to get fish
                mix_img = imageCalculator.run(crop_img, mask_img, "Average create")
                ij.IJ.saveAsTiff(mix_img, os.path.normpath(f"{metaimg_subfolder}/{seN}--MIX.tif"))
                # mix_img.show()
                mix_img.hide()
                
                rm.save(os.path.normpath(f"{metaimg_subfolder}/{seN}_RoiSet.zip"))
                ij.IJ.saveAs("Results", os.path.normpath(f"{dir_result}/{seN}_AutoAnalysis.csv"))
                rm.runCommand("Deselect")
                rm.runCommand("Delete") # delete ROI, otherwise, it increases infinitely
            else:
                log.info(f'      ROI in RoiManager: {rm_size}')
                log.info(f'      #### ERROR : Number of ROI not = 1')
                # Write Log
                log_writer.write(f"|         number of ROI = {rm_size} \n")
                log_writer.write("| #### ERROR : Number of ROI not = 1 \n") # ERROR:
                
                if (rm_size > 1): # delete ROI, otherwise, it increases infinitely
                    rm.runCommand("Deselect")
                    rm.runCommand("Delete")
        
        else: log.info("      #### WARNING : Can't find any Slices in this image --> skip this image") # WARNING:


        log_writer.write(f"| \n") # make Log file looks better.
        ij.IJ.run("Clear Results", "")
        ij.IJ.run("Close All", "")
    
    
    log.info("\n") # make CLI output looks better.


log_writer.close()
rm.close()
ij.WindowManager.closeAllWindows()

log.info(" -- finished --")
# Out:
# | 2023-02-15 08:58:17,392 | {Test}_BF_analysis | INFO | lif_path_list <class 'list'>: ['C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220610 CE001 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220613 CE001 palmskin_11dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220617 CE002 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220620 CE002 palmskin_11dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220621 CE003 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220623 CE003 palmskin_10dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220623 CE004 palmskin_7dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220624 CE004 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220627 CE006 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220628 CE006 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220708 CE009 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220711 CE009 palmskin_11dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220719 CE011 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220725 CE012 palmskin_7dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220727 CE012 palmskin_9dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220816 AI001 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220818 AI001 palmskin_10dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220823 AI002 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220825 AI002 palmskin_10dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220830-AI003-palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_ ...
#
# | 2023-02-15 08:58:17,394 | {Test}_BF_analysis | INFO | Processing ... 1/25
# | 2023-02-15 08:58:17,410 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220610 CE001 palmskin_8dpf.lif
# | 2023-02-15 08:58:17,411 | {Test}_BF_analysis | INFO | seriesCount : 6
# | 2023-02-15 08:58:17,853 | {Test}_BF_analysis | INFO | series 1/6 : '20220610_CE001_palmskin_8dpf - Series001_fish_1' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:18,427 | {Test}_BF_analysis | INFO | series 2/6 : '20220610_CE001_palmskin_8dpf - Series003_fish_2' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:18,812 | {Test}_BF_analysis | INFO | series 3/6 : '20220610_CE001_palmskin_8dpf - Series003_fish_3' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:19,426 | {Test}_BF_analysis | INFO | series 4/6 : '20220610_CE001_palmskin_8dpf - Series004_fish_4' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:19,837 | {Test}_BF_analysis | INFO | series 5/6 : '20220610_CE001_palmskin_8dpf - Series005_fish_5' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:20,214 | {Test}_BF_analysis | INFO | series 6/6 : '20220610_CE001_palmskin_8dpf - Series006_fish_6' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:20,373 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:20,375 | {Test}_BF_analysis | INFO | Processing ... 2/25
# | 2023-02-15 08:58:20,396 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220613 CE001 palmskin_11dpf.lif
# | 2023-02-15 08:58:20,397 | {Test}_BF_analysis | INFO | seriesCount : 4
# | 2023-02-15 08:58:20,596 | {Test}_BF_analysis | INFO | series 1/4 : '20220613_CE001_palmskin_11dpf - Series001_fish_7' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:20,939 | {Test}_BF_analysis | INFO | series 2/4 : '20220613_CE001_palmskin_11dpf - Series002_fish_8' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:21,297 | {Test}_BF_analysis | INFO | series 3/4 : '20220613_CE001_palmskin_11dpf - Series003_fish_9' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:21,794 | {Test}_BF_analysis | INFO | series 4/4 : '20220613_CE001_palmskin_11dpf - Series004_fish_10' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:21,961 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:21,961 | {Test}_BF_analysis | INFO | Processing ... 3/25
# | 2023-02-15 08:58:21,973 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220617 CE002 palmskin_8dpf.lif
# | 2023-02-15 08:58:21,974 | {Test}_BF_analysis | INFO | seriesCount : 7
# | 2023-02-15 08:58:22,168 | {Test}_BF_analysis | INFO | series 1/7 : '20220617_CE002_palmskin_8dpf - Series001_fish_11_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:22,631 | {Test}_BF_analysis | INFO | series 2/7 : '20220617_CE002_palmskin_8dpf - Series002_fish_12_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:22,632 | {Test}_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-02-15 08:58:23,479 | {Test}_BF_analysis | INFO | series 3/7 : '20220617_CE002_palmskin_8dpf - Series003_fish_13_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:23,480 | {Test}_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-02-15 08:58:24,081 | {Test}_BF_analysis | INFO | series 4/7 : '20220617_CE002_palmskin_8dpf - Series004_fish_14_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:24,082 | {Test}_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-02-15 08:58:24,709 | {Test}_BF_analysis | INFO | series 5/7 : '20220617_CE002_palmskin_8dpf - Series005_fish_15_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:24,710 | {Test}_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-02-15 08:58:25,599 | {Test}_BF_analysis | INFO | series 6/7 : '20220617_CE002_palmskin_8dpf - Series006_fish_16_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:25,600 | {Test}_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-02-15 08:58:26,196 | {Test}_BF_analysis | INFO | series 7/7 : '20220617_CE002_palmskin_8dpf - Series006_fish_16_palmskin_8dpf_000' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:26,197 | {Test}_BF_analysis | INFO |       #### WARNING : Detect ' fish_id ' is same as previous processed fish --> skip this image
# | 2023-02-15 08:58:26,197 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:26,198 | {Test}_BF_analysis | INFO | Processing ... 4/25
# | 2023-02-15 08:58:26,213 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220620 CE002 palmskin_11dpf.lif
# | 2023-02-15 08:58:26,213 | {Test}_BF_analysis | INFO | seriesCount : 6
# | 2023-02-15 08:58:26,414 | {Test}_BF_analysis | INFO | series 1/6 : '20220620_CE002_palmskin_11dpf - Series001_fish_17_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:26,773 | {Test}_BF_analysis | INFO | series 2/6 : '20220620_CE002_palmskin_11dpf - Series002_fish_18_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:27,126 | {Test}_BF_analysis | INFO | series 3/6 : '20220620_CE002_palmskin_11dpf - Series003_fish_19_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:27,478 | {Test}_BF_analysis | INFO | series 4/6 : '20220620_CE002_palmskin_11dpf - Series004_fish_20_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:27,840 | {Test}_BF_analysis | INFO | series 5/6 : '20220620_CE002_palmskin_11dpf - Series005_fish_21_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:28,189 | {Test}_BF_analysis | INFO | series 6/6 : '20220620_CE002_palmskin_11dpf - Series006_fish_22_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:28,349 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:28,350 | {Test}_BF_analysis | INFO | Processing ... 5/25
# | 2023-02-15 08:58:28,367 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220621 CE003 palmskin_8dpf.lif
# | 2023-02-15 08:58:28,368 | {Test}_BF_analysis | INFO | seriesCount : 8
# | 2023-02-15 08:58:28,673 | {Test}_BF_analysis | INFO | series 1/8 : '20220621_CE003_palmskin_8dpf - Series001_fish_23_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:29,017 | {Test}_BF_analysis | INFO | series 2/8 : '20220621_CE003_palmskin_8dpf - Series002_fish_24_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:29,379 | {Test}_BF_analysis | INFO | series 3/8 : '20220621_CE003_palmskin_8dpf - Series003_fish_25_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:29,736 | {Test}_BF_analysis | INFO | series 4/8 : '20220621_CE003_palmskin_8dpf - Series004_fish_26_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:30,092 | {Test}_BF_analysis | INFO | series 5/8 : '20220621_CE003_palmskin_8dpf - Series004_fish_27_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:30,455 | {Test}_BF_analysis | INFO | series 6/8 : '20220621_CE003_palmskin_8dpf - Series005_fish_28_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:30,814 | {Test}_BF_analysis | INFO | series 7/8 : '20220621_CE003_palmskin_8dpf - Series006_fish_29_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:31,168 | {Test}_BF_analysis | INFO | series 8/8 : '20220621_CE003_palmskin_8dpf - Series007_fish_30_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:31,324 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:31,325 | {Test}_BF_analysis | INFO | Processing ... 6/25
# | 2023-02-15 08:58:31,337 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220623 CE003 palmskin_10dpf.lif
# | 2023-02-15 08:58:31,338 | {Test}_BF_analysis | INFO | seriesCount : 4
# | 2023-02-15 08:58:31,522 | {Test}_BF_analysis | INFO | series 1/4 : '20220623_CE003_palmskin_10dpf - Series001_fish_31_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:32,088 | {Test}_BF_analysis | INFO | series 2/4 : '20220623_CE003_palmskin_10dpf - Series002_fish_32_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:32,426 | {Test}_BF_analysis | INFO | series 3/4 : '20220623_CE003_palmskin_10dpf - Series003_fish_33_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:32,763 | {Test}_BF_analysis | INFO | series 4/4 : '20220623_CE003_palmskin_10dpf - Series004_fish_34_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:32,930 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:32,931 | {Test}_BF_analysis | INFO | Processing ... 7/25
# | 2023-02-15 08:58:32,941 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220623 CE004 palmskin_7dpf.lif
# | 2023-02-15 08:58:32,942 | {Test}_BF_analysis | INFO | seriesCount : 8
# | 2023-02-15 08:58:33,141 | {Test}_BF_analysis | INFO | series 1/8 : '20220623_CE004_palmskin_7dpf - Series001_fish_35_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:33,498 | {Test}_BF_analysis | INFO | series 2/8 : '20220623_CE004_palmskin_7dpf - Series002_fish_36_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:33,872 | {Test}_BF_analysis | INFO | series 3/8 : '20220623_CE004_palmskin_7dpf - Series003_fish_37_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:34,235 | {Test}_BF_analysis | INFO | series 4/8 : '20220623_CE004_palmskin_7dpf - Series004_fish_38_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:34,577 | {Test}_BF_analysis | INFO | series 5/8 : '20220623_CE004_palmskin_7dpf - Series005_fish_39_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:34,937 | {Test}_BF_analysis | INFO | series 6/8 : '20220623_CE004_palmskin_7dpf - Series006_fish_40_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:35,293 | {Test}_BF_analysis | INFO | series 7/8 : '20220623_CE004_palmskin_7dpf - Series007_fish_41_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:35,719 | {Test}_BF_analysis | INFO | series 8/8 : '20220623_CE004_palmskin_7dpf - Series008_fish_42_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:35,885 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:35,886 | {Test}_BF_analysis | INFO | Processing ... 8/25
# | 2023-02-15 08:58:35,936 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220624 CE004 palmskin_8dpf.lif
# | 2023-02-15 08:58:35,936 | {Test}_BF_analysis | INFO | seriesCount : 13
# | 2023-02-15 08:58:36,167 | {Test}_BF_analysis | INFO | series  1/13 : '20220624_CE004_palmskin_8dpf - Series001_fish_43_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:36,550 | {Test}_BF_analysis | INFO | series  2/13 : '20220624_CE004_palmskin_8dpf - Series002_fish_44_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:36,938 | {Test}_BF_analysis | INFO | series  3/13 : '20220624_CE004_palmskin_8dpf - Series003_fish_45_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:37,314 | {Test}_BF_analysis | INFO | series  4/13 : '20220624_CE004_palmskin_8dpf - Series004_fish_46_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:37,687 | {Test}_BF_analysis | INFO | series  5/13 : '20220624_CE004_palmskin_8dpf - Series005_fish_47_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:38,055 | {Test}_BF_analysis | INFO | series  6/13 : '20220624_CE004_palmskin_8dpf - Series006_fish_48_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:38,421 | {Test}_BF_analysis | INFO | series  7/13 : '20220624_CE004_palmskin_8dpf - Series007_fish_49_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:38,802 | {Test}_BF_analysis | INFO | series  8/13 : '20220624_CE004_palmskin_8dpf - Series008_fish_50_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:39,172 | {Test}_BF_analysis | INFO | series  9/13 : '20220624_CE004_palmskin_8dpf - Series009_fish_51_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:39,718 | {Test}_BF_analysis | INFO | series 10/13 : '20220624_CE004_palmskin_8dpf - Series010_fish_52_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:40,103 | {Test}_BF_analysis | INFO | series 11/13 : '20220624_CE004_palmskin_8dpf - Series011_fish_53_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:40,496 | {Test}_BF_analysis | INFO | series 12/13 : '20220624_CE004_palmskin_8dpf - Series012_fish_54_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:40,875 | {Test}_BF_analysis | INFO | series 13/13 : '20220624_CE004_palmskin_8dpf - Series013_fish_55_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:41,050 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:41,052 | {Test}_BF_analysis | INFO | Processing ... 9/25
# | 2023-02-15 08:58:41,066 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220627 CE006 palmskin_8dpf.lif
# | 2023-02-15 08:58:41,066 | {Test}_BF_analysis | INFO | seriesCount : 10
# | 2023-02-15 08:58:41,268 | {Test}_BF_analysis | INFO | series  1/10 : '20220627_CE006_palmskin_8dpf - Series001_fish_56_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:41,625 | {Test}_BF_analysis | INFO | series  2/10 : '20220627_CE006_palmskin_8dpf - Series002_fish_57_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:41,983 | {Test}_BF_analysis | INFO | series  3/10 : '20220627_CE006_palmskin_8dpf - Series003_fish_58_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:42,348 | {Test}_BF_analysis | INFO | series  4/10 : '20220627_CE006_palmskin_8dpf - Series004_fish_59_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:42,721 | {Test}_BF_analysis | INFO | series  5/10 : '20220627_CE006_palmskin_8dpf - Series005_fish_60_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:43,103 | {Test}_BF_analysis | INFO | series  6/10 : '20220627_CE006_palmskin_8dpf - Series006_fish_61_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:43,488 | {Test}_BF_analysis | INFO | series  7/10 : '20220627_CE006_palmskin_8dpf - Series007_fish_62_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:43,851 | {Test}_BF_analysis | INFO | series  8/10 : '20220627_CE006_palmskin_8dpf - Series008_fish_63_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:44,228 | {Test}_BF_analysis | INFO | series  9/10 : '20220627_CE006_palmskin_8dpf - Series009_fish_64_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:44,597 | {Test}_BF_analysis | INFO | series 10/10 : '20220627_CE006_palmskin_8dpf - Series010_fish_65_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:44,765 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:44,768 | {Test}_BF_analysis | INFO | Processing ... 10/25
# | 2023-02-15 08:58:44,784 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220628 CE006 palmskin_8dpf.lif
# | 2023-02-15 08:58:44,785 | {Test}_BF_analysis | INFO | seriesCount : 8
# | 2023-02-15 08:58:44,976 | {Test}_BF_analysis | INFO | series 1/8 : '20220628_CE006_palmskin_8dpf - Series001_fish_66_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:45,321 | {Test}_BF_analysis | INFO | series 2/8 : '20220628_CE006_palmskin_8dpf - Series002_fish_67_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:45,680 | {Test}_BF_analysis | INFO | series 3/8 : '20220628_CE006_palmskin_8dpf - Series003_fish_68_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:46,027 | {Test}_BF_analysis | INFO | series 4/8 : '20220628_CE006_palmskin_8dpf - Series004_fish_69_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:46,385 | {Test}_BF_analysis | INFO | series 5/8 : '20220628_CE006_palmskin_8dpf - Series005_fish_70_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:46,733 | {Test}_BF_analysis | INFO | series 6/8 : '20220628_CE006_palmskin_8dpf - Series006_fish_71_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:47,084 | {Test}_BF_analysis | INFO | series 7/8 : '20220628_CE006_palmskin_8dpf - Series007_fish_72_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:47,570 | {Test}_BF_analysis | INFO | series 8/8 : '20220628_CE006_palmskin_8dpf - Series008_fish_73_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:47,737 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:47,738 | {Test}_BF_analysis | INFO | Processing ... 11/25
# | 2023-02-15 08:58:47,750 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220708 CE009 palmskin_8dpf.lif
# | 2023-02-15 08:58:47,751 | {Test}_BF_analysis | INFO | seriesCount : 11
# | 2023-02-15 08:58:47,954 | {Test}_BF_analysis | INFO | series  1/11 : '20220708_CE009_palmskin_8dpf - Series001_fish_74_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:48,317 | {Test}_BF_analysis | INFO | series  2/11 : '20220708_CE009_palmskin_8dpf - Series002_fish_75_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:48,397 | {Test}_BF_analysis | INFO |       ROI in RoiManager: 2
# | 2023-02-15 08:58:48,397 | {Test}_BF_analysis | INFO |       #### ERROR : Number of ROI not = 1
# | 2023-02-15 08:58:48,669 | {Test}_BF_analysis | INFO | series  3/11 : '20220708_CE009_palmskin_8dpf - Series003_fish_76_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:49,037 | {Test}_BF_analysis | INFO | series  4/11 : '20220708_CE009_palmskin_8dpf - Series004_fish_77_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:49,394 | {Test}_BF_analysis | INFO | series  5/11 : '20220708_CE009_palmskin_8dpf - Series005_fish_78_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:49,752 | {Test}_BF_analysis | INFO | series  6/11 : '20220708_CE009_palmskin_8dpf - Series006_fish_80_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:50,112 | {Test}_BF_analysis | INFO | series  7/11 : '20220708_CE009_palmskin_8dpf - Series007_fish_81_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:50,461 | {Test}_BF_analysis | INFO | series  8/11 : '20220708_CE009_palmskin_8dpf - Series009_fish_82_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:50,826 | {Test}_BF_analysis | INFO | series  9/11 : '20220708_CE009_palmskin_8dpf - Series010_fish_83_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:51,193 | {Test}_BF_analysis | INFO | series 10/11 : '20220708_CE009_palmskin_8dpf - Series011_fish_84_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:51,597 | {Test}_BF_analysis | INFO | series 11/11 : '20220708_CE009_palmskin_8dpf - Series012_fish_85_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:51,750 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:51,751 | {Test}_BF_analysis | INFO | Processing ... 12/25
# | 2023-02-15 08:58:51,763 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220711 CE009 palmskin_11dpf.lif
# | 2023-02-15 08:58:51,764 | {Test}_BF_analysis | INFO | seriesCount : 5
# | 2023-02-15 08:58:51,963 | {Test}_BF_analysis | INFO | series 1/5 : '20220711_CE009_palmskin_11dpf - Series001_fish_86_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:52,305 | {Test}_BF_analysis | INFO | series 2/5 : '20220711_CE009_palmskin_11dpf - series003_fish_88_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:52,651 | {Test}_BF_analysis | INFO | series 3/5 : '20220711_CE009_palmskin_11dpf - Series005_fish_90_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:52,992 | {Test}_BF_analysis | INFO | series 4/5 : '20220711_CE009_palmskin_11dpf - Series006_fish_91_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:53,341 | {Test}_BF_analysis | INFO | series 5/5 : '20220711_CE009_palmskin_11dpf - Series007_fish_92_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:53,500 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:53,501 | {Test}_BF_analysis | INFO | Processing ... 13/25
# | 2023-02-15 08:58:53,512 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220719 CE011 palmskin_8dpf.lif
# | 2023-02-15 08:58:53,512 | {Test}_BF_analysis | INFO | seriesCount : 8
# | 2023-02-15 08:58:53,702 | {Test}_BF_analysis | INFO | series 1/8 : '20220719_CE011_palmskin_8dpf - Series001_fish_94_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:54,060 | {Test}_BF_analysis | INFO | series 2/8 : '20220719_CE011_palmskin_8dpf - Series002_fish_95_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:54,409 | {Test}_BF_analysis | INFO | series 3/8 : '20220719_CE011_palmskin_8dpf - Series003_fish_96_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:54,770 | {Test}_BF_analysis | INFO | series 4/8 : '20220719_CE011_palmskin_8dpf - Series004_fish_97_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:55,129 | {Test}_BF_analysis | INFO | series 5/8 : '20220719_CE011_palmskin_8dpf - Series005_fish_98_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:55,551 | {Test}_BF_analysis | INFO | series 6/8 : '20220719_CE011_palmskin_8dpf - Series006_fish_99_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:55,899 | {Test}_BF_analysis | INFO | series 7/8 : '20220719_CE011_palmskin_8dpf - Series007_fish_100_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:56,252 | {Test}_BF_analysis | INFO | series 8/8 : '20220719_CE011_palmskin_8dpf - Series008_fish_101_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:56,409 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:56,410 | {Test}_BF_analysis | INFO | Processing ... 14/25
# | 2023-02-15 08:58:56,421 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220725 CE012 palmskin_7dpf.lif
# | 2023-02-15 08:58:56,422 | {Test}_BF_analysis | INFO | seriesCount : 9
# | 2023-02-15 08:58:56,621 | {Test}_BF_analysis | INFO | series 1/9 : '20220725_CE012_palmskin_7dpf - Series001_fish_102_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:56,974 | {Test}_BF_analysis | INFO | series 2/9 : '20220725_CE012_palmskin_7dpf - Series002_fish_103_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:57,326 | {Test}_BF_analysis | INFO | series 3/9 : '20220725_CE012_palmskin_7dpf - Series003_fish_104_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:57,672 | {Test}_BF_analysis | INFO | series 4/9 : '20220725_CE012_palmskin_7dpf - Series004_fish_105_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:58,032 | {Test}_BF_analysis | INFO | series 5/9 : '20220725_CE012_palmskin_7dpf - Series005_fish_106_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:58,385 | {Test}_BF_analysis | INFO | series 6/9 : '20220725_CE012_palmskin_7dpf - Series006_fish_107_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:58,732 | {Test}_BF_analysis | INFO | series 7/9 : '20220725_CE012_palmskin_7dpf - Series007_fish_108_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:59,091 | {Test}_BF_analysis | INFO | series 8/9 : '20220725_CE012_palmskin_7dpf - Series008_fish_109_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:59,446 | {Test}_BF_analysis | INFO | series 9/9 : '20220725_CE012_palmskin_7dpf - Series009_fish_110_palmskin_7dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:58:59,614 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:58:59,614 | {Test}_BF_analysis | INFO | Processing ... 15/25
# | 2023-02-15 08:58:59,623 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220727 CE012 palmskin_9dpf.lif
# | 2023-02-15 08:58:59,624 | {Test}_BF_analysis | INFO | seriesCount : 7
# | 2023-02-15 08:59:00,004 | {Test}_BF_analysis | INFO | series 1/7 : '20220727_CE012_palmskin_9dpf - Series001_fish_111_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:00,360 | {Test}_BF_analysis | INFO | series 2/7 : '20220727_CE012_palmskin_9dpf - Series002_fish_112_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:00,711 | {Test}_BF_analysis | INFO | series 3/7 : '20220727_CE012_palmskin_9dpf - Series003_fish_113_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:01,062 | {Test}_BF_analysis | INFO | series 4/7 : '20220727_CE012_palmskin_9dpf - Series004_fish_114_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:01,409 | {Test}_BF_analysis | INFO | series 5/7 : '20220727_CE012_palmskin_9dpf - Series005_fish_115_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:01,749 | {Test}_BF_analysis | INFO | series 6/7 : '20220727_CE012_palmskin_9dpf - Series006_fish_116_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:02,095 | {Test}_BF_analysis | INFO | series 7/7 : '20220727_CE012_palmskin_9dpf - Series007_fish_117_palmskin_9dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:02,265 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:02,266 | {Test}_BF_analysis | INFO | Processing ... 16/25
# | 2023-02-15 08:59:02,272 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220816 AI001 palmskin_8dpf.lif
# | 2023-02-15 08:59:02,273 | {Test}_BF_analysis | INFO | seriesCount : 1
# | 2023-02-15 08:59:02,430 | {Test}_BF_analysis | INFO | series 1/1 : '20220816_AI001_palmskin_8dpf - Series001_fish_118_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:02,594 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:02,595 | {Test}_BF_analysis | INFO | Processing ... 17/25
# | 2023-02-15 08:59:02,602 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220818 AI001 palmskin_10dpf.lif
# | 2023-02-15 08:59:02,603 | {Test}_BF_analysis | INFO | seriesCount : 1
# | 2023-02-15 08:59:02,770 | {Test}_BF_analysis | INFO | series 1/1 : '20220818_AI001_palmskin_10dpf - Series001_fish_119_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:02,950 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:02,951 | {Test}_BF_analysis | INFO | Processing ... 18/25
# | 2023-02-15 08:59:02,959 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220823 AI002 palmskin_8dpf.lif
# | 2023-02-15 08:59:02,959 | {Test}_BF_analysis | INFO | seriesCount : 5
# | 2023-02-15 08:59:03,142 | {Test}_BF_analysis | INFO | series 1/5 : '20220823_AI002_palmskin_8dpf - Series001_fish_120_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:03,481 | {Test}_BF_analysis | INFO | series 2/5 : '20220823_AI002_palmskin_8dpf - Series002_fish_121_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:03,841 | {Test}_BF_analysis | INFO | series 3/5 : '20220823_AI002_palmskin_8dpf - Series003_fish_122_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:04,185 | {Test}_BF_analysis | INFO | series 4/5 : '20220823_AI002_palmskin_8dpf - Series004_fish_123_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:04,540 | {Test}_BF_analysis | INFO | series 5/5 : '20220823_AI002_palmskin_8dpf - Series005_fish_124_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:04,704 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:04,705 | {Test}_BF_analysis | INFO | Processing ... 19/25
# | 2023-02-15 08:59:04,715 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220825 AI002 palmskin_10dpf.lif
# | 2023-02-15 08:59:04,716 | {Test}_BF_analysis | INFO | seriesCount : 10
# | 2023-02-15 08:59:04,944 | {Test}_BF_analysis | INFO | series  1/10 : '20220825_AI002_palmskin_10dpf - Series001_fish_125_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:05,314 | {Test}_BF_analysis | INFO | series  2/10 : '20220825_AI002_palmskin_10dpf - Series002_fish_126_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:05,671 | {Test}_BF_analysis | INFO | series  3/10 : '20220825_AI002_palmskin_10dpf - Series003_fish_127_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:06,031 | {Test}_BF_analysis | INFO | series  4/10 : '20220825_AI002_palmskin_10dpf - Series004_fish_128_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:06,387 | {Test}_BF_analysis | INFO | series  5/10 : '20220825_AI002_palmskin_10dpf - Series005_fish_129_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:06,748 | {Test}_BF_analysis | INFO | series  6/10 : '20220825_AI002_palmskin_10dpf - Series006_fish_130_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:07,119 | {Test}_BF_analysis | INFO | series  7/10 : '20220825_AI002_palmskin_10dpf - Series007_fish_131_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:07,487 | {Test}_BF_analysis | INFO | series  8/10 : '20220825_AI002_palmskin_10dpf - Series008_fish_132_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:07,846 | {Test}_BF_analysis | INFO | series  9/10 : '20220825_AI002_palmskin_10dpf - Series009_fish_133_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:08,203 | {Test}_BF_analysis | INFO | series 10/10 : '20220825_AI002_palmskin_10dpf - Series010_fish_134_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:08,367 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:08,368 | {Test}_BF_analysis | INFO | Processing ... 20/25
# | 2023-02-15 08:59:08,378 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220830-AI003-palmskin_8dpf.lif
# | 2023-02-15 08:59:08,379 | {Test}_BF_analysis | INFO | seriesCount : 7
# | 2023-02-15 08:59:08,573 | {Test}_BF_analysis | INFO | series 1/7 : '20220830_AI003_palmskin_8dpf - Series001_fish_135_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:08,939 | {Test}_BF_analysis | INFO | series 2/7 : '20220830_AI003_palmskin_8dpf - Series002_fish_136_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:09,292 | {Test}_BF_analysis | INFO | series 3/7 : '20220830_AI003_palmskin_8dpf - Series003_fish_137_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:09,795 | {Test}_BF_analysis | INFO | series 4/7 : '20220830_AI003_palmskin_8dpf - Series004_fish_138_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:10,151 | {Test}_BF_analysis | INFO | series 5/7 : '20220830_AI003_palmskin_8dpf - Series005_fish_139_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:10,516 | {Test}_BF_analysis | INFO | series 6/7 : '20220830_AI003_palmskin_8dpf - Series006_fish_140_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:10,869 | {Test}_BF_analysis | INFO | series 7/7 : '20220830_AI003_palmskin_8dpf - Series007_fish_141_palmskin_8dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:11,044 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:11,045 | {Test}_BF_analysis | INFO | Processing ... 21/25
# | 2023-02-15 08:59:11,059 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220901-AI003-palmskin_10dpf.lif
# | 2023-02-15 08:59:11,060 | {Test}_BF_analysis | INFO | seriesCount : 12
# | 2023-02-15 08:59:11,266 | {Test}_BF_analysis | INFO | series  1/12 : '20220901_AI003_palmskin_10dpf - Series001_fish_142_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:11,632 | {Test}_BF_analysis | INFO | series  2/12 : '20220901_AI003_palmskin_10dpf - Series002_fish_143_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:12,000 | {Test}_BF_analysis | INFO | series  3/12 : '20220901_AI003_palmskin_10dpf - Series003_fish_144_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:12,360 | {Test}_BF_analysis | INFO | series  4/12 : '20220901_AI003_palmskin_10dpf - Series004_fish_145_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:12,723 | {Test}_BF_analysis | INFO | series  5/12 : '20220901_AI003_palmskin_10dpf - Series005_fish_146_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:13,087 | {Test}_BF_analysis | INFO | series  6/12 : '20220901_AI003_palmskin_10dpf - Series006_fish_147_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:13,457 | {Test}_BF_analysis | INFO | series  7/12 : '20220901_AI003_palmskin_10dpf - Series007_fish_148_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:13,821 | {Test}_BF_analysis | INFO | series  8/12 : '20220901_AI003_palmskin_10dpf - Series008_fish_149_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:14,199 | {Test}_BF_analysis | INFO | series  9/12 : '20220901_AI003_palmskin_10dpf - Series009_fish_150_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:14,632 | {Test}_BF_analysis | INFO | series 10/12 : '20220901_AI003_palmskin_10dpf - Series010_fish_151_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:15,008 | {Test}_BF_analysis | INFO | series 11/12 : '20220901_AI003_palmskin_10dpf - Series011_fish_152_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:15,382 | {Test}_BF_analysis | INFO | series 12/12 : '20220901_AI003_palmskin_10dpf - Series012_fish_153_palmskin_10dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:15,556 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:15,556 | {Test}_BF_analysis | INFO | Processing ... 22/25
# | 2023-02-15 08:59:15,570 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20221014-AI004-palmskin_11dpf.lif
# | 2023-02-15 08:59:15,571 | {Test}_BF_analysis | INFO | seriesCount : 11
# | 2023-02-15 08:59:15,777 | {Test}_BF_analysis | INFO | series  1/11 : '20221014_AI004_palmskin_11dpf - Series001_fish_154_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:16,139 | {Test}_BF_analysis | INFO | series  2/11 : '20221014_AI004_palmskin_11dpf - Series002_fish_155_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:16,494 | {Test}_BF_analysis | INFO | series  3/11 : '20221014_AI004_palmskin_11dpf - Series003_fish_156_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:16,858 | {Test}_BF_analysis | INFO | series  4/11 : '20221014_AI004_palmskin_11dpf - Series004_fish_157_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:17,210 | {Test}_BF_analysis | INFO | series  5/11 : '20221014_AI004_palmskin_11dpf - Series005_fish_158_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:17,564 | {Test}_BF_analysis | INFO | series  6/11 : '20221014_AI004_palmskin_11dpf - Series006_fish_159_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:17,920 | {Test}_BF_analysis | INFO | series  7/11 : '20221014_AI004_palmskin_11dpf - Series007_fish_160_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:18,280 | {Test}_BF_analysis | INFO | series  8/11 : '20221014_AI004_palmskin_11dpf - Series008_fish_161_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:18,642 | {Test}_BF_analysis | INFO | series  9/11 : '20221014_AI004_palmskin_11dpf - Series009_fish_162_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:19,017 | {Test}_BF_analysis | INFO | series 10/11 : '20221014_AI004_palmskin_11dpf - Series010_fish_163_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:19,384 | {Test}_BF_analysis | INFO | series 11/11 : '20221014_AI004_palmskin_11dpf - Series011_fish_164_palmskin_11dpf' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:19,697 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:19,698 | {Test}_BF_analysis | INFO | Processing ... 23/25
# | 2023-02-15 08:59:19,716 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Upload_20221209\20221125_AI005_palmskin_10dpf.lif
# | 2023-02-15 08:59:19,716 | {Test}_BF_analysis | INFO | seriesCount : 21
# | 2023-02-15 08:59:19,959 | {Test}_BF_analysis | INFO | series  1/21 : '20221125_AI005_palmskin_10dpf - Series001_fish_165_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:20,367 | {Test}_BF_analysis | INFO | series  2/21 : '20221125_AI005_palmskin_10dpf - Series002_fish_166_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:20,773 | {Test}_BF_analysis | INFO | series  3/21 : '20221125_AI005_palmskin_10dpf - Series003_fish_167_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:21,182 | {Test}_BF_analysis | INFO | series  4/21 : '20221125_AI005_palmskin_10dpf - Series004_fish_168_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:21,581 | {Test}_BF_analysis | INFO | series  5/21 : '20221125_AI005_palmskin_10dpf - Series005_fish_169_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:21,990 | {Test}_BF_analysis | INFO | series  6/21 : '20221125_AI005_palmskin_10dpf - Series006_fish_170_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:22,396 | {Test}_BF_analysis | INFO | series  7/21 : '20221125_AI005_palmskin_10dpf - Series007_fish_171_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:22,799 | {Test}_BF_analysis | INFO | series  8/21 : '20221125_AI005_palmskin_10dpf - Series008_fish_172_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:23,195 | {Test}_BF_analysis | INFO | series  9/21 : '20221125_AI005_palmskin_10dpf - Series009_fish_173_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:23,600 | {Test}_BF_analysis | INFO | series 10/21 : '20221125_AI005_palmskin_10dpf - Series010_fish_174_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:24,010 | {Test}_BF_analysis | INFO | series 11/21 : '20221125_AI005_palmskin_10dpf - Series011_fish_175_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:24,428 | {Test}_BF_analysis | INFO | series 12/21 : '20221125_AI005_palmskin_10dpf - Series012_fish_176_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:24,831 | {Test}_BF_analysis | INFO | series 13/21 : '20221125_AI005_palmskin_10dpf - Series013_fish_177_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:25,256 | {Test}_BF_analysis | INFO | series 14/21 : '20221125_AI005_palmskin_10dpf - Series014_fish_178_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:25,678 | {Test}_BF_analysis | INFO | series 15/21 : '20221125_AI005_palmskin_10dpf - Series015_fish179_BF_delete' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:26,095 | {Test}_BF_analysis | INFO | series 16/21 : '20221125_AI005_palmskin_10dpf - Series016_fish_180_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:26,499 | {Test}_BF_analysis | INFO | series 17/21 : '20221125_AI005_palmskin_10dpf - Series017_fish_181_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:26,906 | {Test}_BF_analysis | INFO | series 18/21 : '20221125_AI005_palmskin_10dpf - Series018_fish_182_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:27,309 | {Test}_BF_analysis | INFO | series 19/21 : '20221125_AI005_palmskin_10dpf - Series019_fish_183_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:27,711 | {Test}_BF_analysis | INFO | series 20/21 : '20221125_AI005_palmskin_10dpf - Series020_fish_184_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:28,128 | {Test}_BF_analysis | INFO | series 21/21 : '20221125_AI005_palmskin_10dpf - Series021_fish_186_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:28,290 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:28,290 | {Test}_BF_analysis | INFO | Processing ... 24/25
# | 2023-02-15 08:59:28,306 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Upload_20221209\20221126_AI005_palmskin_11dpf.lif
# | 2023-02-15 08:59:28,307 | {Test}_BF_analysis | INFO | seriesCount : 16
# | 2023-02-15 08:59:28,522 | {Test}_BF_analysis | INFO | series  1/16 : '20221126_AI005_palmskin_11dpf - Series001_fish_187_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:28,988 | {Test}_BF_analysis | INFO | series  2/16 : '20221126_AI005_palmskin_11dpf - Series002_fish_188_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:29,369 | {Test}_BF_analysis | INFO | series  3/16 : '20221126_AI005_palmskin_11dpf - Series003_fish_189_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:29,754 | {Test}_BF_analysis | INFO | series  4/16 : '20221126_AI005_palmskin_11dpf - Series004_fish_190_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:30,134 | {Test}_BF_analysis | INFO | series  5/16 : '20221126_AI005_palmskin_11dpf - Series005_fish_191_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:30,517 | {Test}_BF_analysis | INFO | series  6/16 : '20221126_AI005_palmskin_11dpf - Series006_fish_192_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:30,884 | {Test}_BF_analysis | INFO | series  7/16 : '20221126_AI005_palmskin_11dpf - Series007_fish_193_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:31,270 | {Test}_BF_analysis | INFO | series  8/16 : '20221126_AI005_palmskin_11dpf - Series008_fish_194_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:31,635 | {Test}_BF_analysis | INFO | series  9/16 : '20221126_AI005_palmskin_11dpf - Series009_fish_195_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:32,025 | {Test}_BF_analysis | INFO | series 10/16 : '20221126_AI005_palmskin_11dpf - Series010_fish_196_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:32,415 | {Test}_BF_analysis | INFO | series 11/16 : '20221126_AI005_palmskin_11dpf - Series011_fish_197_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:32,793 | {Test}_BF_analysis | INFO | series 12/16 : '20221126_AI005_palmskin_11dpf - Series012_fish_198_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:33,171 | {Test}_BF_analysis | INFO | series 13/16 : '20221126_AI005_palmskin_11dpf - Series013_fish_199_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:33,549 | {Test}_BF_analysis | INFO | series 14/16 : '20221126_AI005_palmskin_11dpf - Series014_fish_200_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:33,926 | {Test}_BF_analysis | INFO | series 15/16 : '20221126_AI005_palmskin_11dpf - Series015_fish_201_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:34,311 | {Test}_BF_analysis | INFO | series 16/16 : '20221126_AI005_palmskin_11dpf - Series016_fish_202_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:34,487 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:34,487 | {Test}_BF_analysis | INFO | Processing ... 25/25
# | 2023-02-15 08:59:34,497 | {Test}_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Upload_20221209\20221127_AI005_palmskin_12dpf.lif
# | 2023-02-15 08:59:34,497 | {Test}_BF_analysis | INFO | seriesCount : 5
# | 2023-02-15 08:59:34,683 | {Test}_BF_analysis | INFO | series 1/5 : '20221127_AI005_palmskin_12dpf - Series001_fish_203_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:35,022 | {Test}_BF_analysis | INFO | series 2/5 : '20221127_AI005_palmskin_12dpf - Series002_fish_204_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:35,361 | {Test}_BF_analysis | INFO | series 3/5 : '20221127_AI005_palmskin_12dpf - Series003_fish_205_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:35,697 | {Test}_BF_analysis | INFO | series 4/5 : '20221127_AI005_palmskin_12dpf - Series004_fish_206_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:36,036 | {Test}_BF_analysis | INFO | series 5/5 : '20221127_AI005_palmskin_12dpf - Series005_fish_207_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames )
# | 2023-02-15 08:59:36,206 | {Test}_BF_analysis | INFO |
#
# | 2023-02-15 08:59:36,245 | {Test}_BF_analysis | INFO |  -- finished --

# %%
log_writer.close()

# %% [markdown]
# # Other Useful Methods
#
# ```
# ij.WindowManager.closeAllWindows()
#
# ij.WindowManager.getCurrentImage()
#
# img.getProperties()
#
# ij.WindowManager.getActiveWindow()
# ```
