# %% [markdown]
# # Initialize PyImageJ

# %%
# Import module
import jpype
# Enable Java imports
import jpype.imports
# Pull in types
from jpype.types import *

import scyjava as sj # scyjava : Supercharged Java access from Python, see https://github.com/scijava/scyjava
import imagej

# Configurations
# NOTE: The ImageJ2 gateway is initialized through a Java Virtual Machine (JVM). If you want to configure the JVM, it must be done before initializing an ImageJ2 gateway.
# sj.config.add_option('-Xmx10g') # adjust memory available to Java
sj.config.endpoints.append('ome:formats-gpl:6.11.1')

# %%
Fiji_Local = r"C:\Users\confocal_microscope\Desktop\Tools\Fiji.app"

# ij = imagej.init(Fiji_Local) # Same as "ij = imagej.init(Fiji_Local, mode='headless')", PyImageJ’s default mode is headless
# ij = imagej.init(Fiji_Local, mode='gui') # GUI mode (會卡在這一行 -> blocking), for more explainations : https://pyimagej.readthedocs.io/en/latest/Initialization.html#gui-mode
ij = imagej.init(Fiji_Local, mode='interactive') # Interactive mode (可以繼續向下執行 -> non-blocking), for more explainations : https://pyimagej.readthedocs.io/en/latest/Initialization.html#interactive-mode
ij.ui().showUI() # display the Fiji GUI

print(ij.getApp().getInfo(True)) # ImageJ2 2.9.0/1.54b
# Out:
# ImageJ2 2.9.0/1.54b; Java 1.8.0_362 [amd64]; 152MB of 14542MB

# %% [markdown]
# # Import Customized modules and Create ImageJ Object

# %%
import os
import sys
import re
from typing import TextIO, Dict
from datetime import datetime
from glob import glob

import json
import logging
import numpy as np


sys.path.append(r"C:\Users\confocal_microscope\Desktop\ZebraFish_AP_POS\modules") # add path to scan customized module

from logger import init_logger
from fileop import create_new_dir
from zebrafish_lifcheck import check_image_name
from composite_ij import dump_info, save_tif_with_SN, group_show, group_hide

# %%
# Bio-Format Reader
loci = jpype.JPackage("loci")
loci.common.DebugTools.setRootLevel("ERROR")
Reader = loci.formats.ImageReader()

# [IMPORTANT] some ImageJ plugins need to be new before use
from ij.plugin.frame import RoiManager
from ij.plugin import ImageCalculator

rm = RoiManager()
imageCalculator = ImageCalculator()

# %%
log = init_logger(r"ImageJ_BF_analysis")

# %% [markdown]
# Test : Get ```seriesCount``` ( Method 1 )

# %%
loci = jpype.JPackage("loci")
loci.common.DebugTools.setRootLevel("ERROR")
Ext = loci.plugins.macro.LociFunctions()

# LociFunctions = sj.jimport("loci.plugins.macro.LociFunctions")
# Ext = LociFunctions()

test_lif = r"C:\Users\confocal_microscope\Desktop\PyImageJ-test-data\BrightField_RAW\20220610_CE001_palmskin_8dpf.lif"

Ext.setId(test_lif)

seriesCount = jpype.java.lang.Double[1]
print(f'seriesCount {type(seriesCount)}: {seriesCount}')
Ext.getSeriesCount(seriesCount)
print(f'seriesCount {type(seriesCount)}: {seriesCount}')

seriesCount = seriesCount[0]
print(f'seriesCount {type(seriesCount)}: {seriesCount}')
Ext.close()
# Out:
# seriesCount <java class 'java.lang.Double[]'>: [None]
# seriesCount <java class 'java.lang.Double[]'>: [6.0]
# seriesCount <java class 'java.lang.Double'>: 6.0

# %% [markdown]
# Test : Get ```seriesCount``` ( Method 2 )

# %%
loci = jpype.JPackage("loci")
loci.common.DebugTools.setRootLevel("ERROR")
Reader = loci.formats.ImageReader()

# ImageReader = sj.jimport("loci.formats.ImageReader")
# Reader = ImageReader()

test_lif = r"C:\Users\confocal_microscope\Desktop\PyImageJ-test-data\BrightField_RAW\20220610_CE001_palmskin_8dpf.lif"

Reader.setId(test_lif)

seriesCount = Reader.getSeriesCount()
print(f'seriesCount {type(seriesCount)}: {seriesCount}')
# Out:
# seriesCount <java class 'JInt'>: 6

# %% [markdown]
# Test : RGB image name

# %%
# test_string = r"Series001_fish_11_palmskin_8dpf"
test_string = r"Series001_fish_207_F"


# Check format of 'image_name'
detect_old_new_list = re.findall("[BF]", test_string)
# print(detect_old_new_list)
image_name_list = re.split(" |_|-", test_string)
if len(detect_old_new_list) > 0: failed_cnt, check_dict = check_image_name(image_name_list, "new_bf", debug_mode=True)
else: failed_cnt, check_dict = check_image_name(image_name_list, "old_bf", debug_mode=True)


# Consociate image_name
if (check_dict["    format_and_type     "] == "old_bf") and (failed_cnt == 0): # name check passed, generate new name
    image_name_list.pop(3) # palmskin (old name only)
    image_name_list.pop(3) # [num]dpf (old name only)
    image_name_list.append("BF")
image_name = "_".join(image_name_list)


# log.info() --> ERRORs when checking 'image_name'
if failed_cnt == -1 : log.info(check_dict["  len(image_name_list)  "])
if failed_cnt > 0 : log.info(check_dict["     failed warning     "])

# log_writer.write() --> ERRORs when checking 'image_name'
if failed_cnt == -1 : print("| {} \n".format(check_dict["  len(image_name_list)  "].strip()))
if failed_cnt > 0: print("| {} \n".format(check_dict["     failed warning     "].strip()))
# Out:
# | 2023-03-03 08:26:25,333 | ImageJ_BF_analysis | INFO |       #### ERROR : image_name, At least 1 test failed: spelling of 'BF'
# failed_cnt = 1
# check_dict \
# {
#   "    format_and_type     ": "new_bf",
#   "  len(image_name_list)  ": "PASS",
#   "  spelling of 'Series'  ": "PASS",
#   "      Series[num]       ": "PASS",
#   "   spelling of 'fish'   ": "PASS",
#   "       fish_[ID]        ": "PASS",
#   "    spelling of 'BF'    ": "FAILED --> 'F', misspelling of 'BF' ",
#   "     failed warning     ": "      #### ERROR : image_name, At least 1 test failed: spelling of 'BF' "
# }
# | #### ERROR : image_name, At least 1 test failed: spelling of 'BF'

# %% [markdown]
# # Start Process

# %% [markdown]
# Original file is ```20220614 macro for SL and SA measurement_by KY.ijm```
#
# Modify by following :
# - using pyimagej
# - bug fix
# - add **```WARNING```** and **```ERROR```** remind
# - make log file pretty
# - see more in [report](../../report/report.md#20230126)

# %%
def single_BF_Analysis(lif_path:str, total_lif_file:int, out_dir_root:str, 
                       log:logging.Logger, log_writer:TextIO, crop_rect:Dict[str, int],
                       micron_per_pixel:float, auto_threshold:str, measure_range:Dict[str, int]):
    
    
    Reader.setId(lif_path)
    log.info(f'LIF_FILE : {lif_path}')
    
    seriesCount = Reader.getSeriesCount()
    # log.info(f'seriesCount : {seriesCount}')
   

    for idx in range(seriesCount):
        
        SeriesNum = idx+1
        
        ij.IJ.run("Bio-Formats Importer", f"open='{lif_path}' color_mode=Default rois_import=[ROI manager] view=Hyperstack stack_order=XYCZT series_{SeriesNum}")
        img = ij.WindowManager.getCurrentImage() # get image, <java class 'ij.ImagePlus'>
        # dump_info(img)
        # img.show()
        img.hide()
        
        
        # Get names and image dimensions
        
        # Consociate "BrightField_RAW" file_name
        file_name = lif_path.split(os.sep)[-1].split(".")[0]
        file_name_list = re.split(" |_|-", file_name)
        assert len(file_name_list) == 4, f"file_name format error, current : '{file_name}', expect like : '20221125_AI005_palmskin_10dpf.lif'"
        file_name = "_".join(file_name_list)
        
        # Get Prop("Image name")
        image_name = img.getProp("Image name")
        image_name = str(image_name)
        
        # Check format of 'image_name'
        detect_old_new_list = re.findall("[BF]", image_name)
        # print(detect_old_new_list)
        image_name_list = re.split(" |_|-", image_name)
        if len(detect_old_new_list) > 0: failed_cnt, check_dict = check_image_name(image_name_list, "new_bf")
        else: failed_cnt, check_dict = check_image_name(image_name_list, "old_bf")
        
        # Consociate image_name
        if (check_dict["    format_and_type     "] == "old_bf") and (failed_cnt == 0): # name check passed, generate new name
            image_name_list.pop(3) # palmskin (old name only)
            image_name_list.pop(3) # [num]dpf (old name only)
            image_name_list.append("BF")
        image_name = "_".join(image_name_list)
        
        # Combine 2 names above
        seN = f"{file_name} - {image_name}"
        
        # Get dimension info
        img_dimensions = img.getDimensions()
        # dim_1
        dim1_length = img.getNumericProperty("Image #0|DimensionDescription #1|Length")
        dim1_elem = img.getNumericProperty("Image #0|DimensionDescription #1|NumberOfElements")
        dim1_unit = dim1_length/(dim1_elem-1)*(10**6)
        # dim_2
        dim2_length = img.getNumericProperty("Image #0|DimensionDescription #2|Length")
        dim2_elem = img.getNumericProperty("Image #0|DimensionDescription #2|NumberOfElements")
        dim2_unit = dim2_length/(dim2_elem-1)*(10**6)
        assert dim1_unit == dim2_unit, f"Voxel_X != Voxel_Y, Voxel_X, Voxel_Y = ({dim1_unit}, {dim2_unit}) micron/pixel"
        log.info(f"series {SeriesNum:{len(str(seriesCount))}}/{seriesCount} : '{seN}' , Dimensions : {img_dimensions} ( width, height, channels, slices, frames ), Voxel_X_Y : {dim1_unit:.4f} micron")
        
        # Print ERRORs when checking 'image_name'
        if failed_cnt == -1 : log.info(check_dict["  len(image_name_list)  "])
        if failed_cnt > 0 : log.info(check_dict["     failed warning     "])
        
        # Write Log
        log_writer.write(f"|-- processing ...  series {SeriesNum:{len(str(seriesCount))}}/{seriesCount} in {SeriesNum}/{total_lif_file} \n")
        log_writer.write(f"|         {seN} \n")
        log_writer.write(f"|         Dimensions : {img_dimensions} ( width, height, channels, slices, frames ), Voxel_X_Y : {dim1_unit:.4f} micron \n")
        if failed_cnt == -1 : log_writer.write("| {} \n".format(check_dict["  len(image_name_list)  "].strip()))
        if failed_cnt > 0: log_writer.write("| {} \n".format(check_dict["     failed warning     "].strip()))
        
        
        # Start image preprocessing
        
        
        # processing var
        tif_save_cnt = 1
        tif_save_SNdigits = "02"
        
        
        # Create sub folder
        if "delete" in seN: subfolder = os.path.join(out_dir_root, "!~delete", seN)
        else: subfolder = os.path.join(out_dir_root, seN)
        dir_metaimg = os.path.join(subfolder, "MetaImage")
        create_new_dir(subfolder, display_in_CLI=False)
        create_new_dir(dir_metaimg, display_in_CLI=False)


        # Find focused slices

        #   Pick up focused slice if slices > 1
        #   Plugin ref : https://sites.google.com/site/qingzongtseng/find-focus
        #   Algorithm  : autofocus algorithm "Normalized variance"  (Groen et al., 1985; Yeo et al., 1993).
        slices = img_dimensions[3]
        if slices > 1:
            log.info("      #### WARNING : Number of Slices > 1, run ' Find focused slices ' ") # WARNING:
            # Write Log
            log_writer.write("| #### WARNING : Number of Slices > 1, run ' Find focused slices ' \n") # WARNING:
            ij.IJ.run(img, "Find focused slices", "select=100 variance=0.000 select_only")
            img = ij.WindowManager.getCurrentImage()
            # img.show()
            img.hide()
        # dump_info(img)
        tif_save_cnt = save_tif_with_SN(img, f"original_16bit", dir_metaimg, tif_save_cnt, tif_save_SNdigits, ij)


        # Convert to 8-bit and Set Scale

        ij.IJ.run("Conversions...", "scale weighted")
        ij.IJ.run(img, "8-bit", "")


        # Consociate the unit ( relationship between micron and pixel )

        #   To prevent some series of images are in different scales, for example, "20220708_CE009_palmskin_8dpf.lif"
        #   Microscope Metadata : 1 pixel = 0.0000065 m = 6.5 micron
        ij.IJ.run(img, "Set Scale...", f"distance=1 known={micron_per_pixel} unit=micron")


        # Cropping image

        img.setRoi(crop_rect["x"], crop_rect["y"], crop_rect["w"], crop_rect["h"])
        crop_img = img.crop()
        tif_save_cnt = save_tif_with_SN(crop_img, f"cropped_BF", subfolder, tif_save_cnt, tif_save_SNdigits, ij)
        

        # Threshold
        
        crop_img_threshold = crop_img.duplicate()
        ij.IJ.run(crop_img_threshold, "Auto Threshold", f"method={auto_threshold} white")
        ij.prefs.blackBackground = True
        ij.IJ.run(crop_img_threshold, "Convert to Mask", "")
        tif_save_cnt = save_tif_with_SN(crop_img_threshold, f"AutoThreshold_{auto_threshold}", dir_metaimg, tif_save_cnt, tif_save_SNdigits, ij)
        

        # SL and SA measurement
        
        ij.IJ.run("Set Measurements...", "area mean min feret's display redirect=None decimal=2")
        ij.IJ.run(crop_img_threshold, "Analyze Particles...", "size={}-{} show=Masks display include add".format(measure_range["lower_bound"], measure_range["upper_bound"]))
        mask_img = ij.WindowManager.getCurrentImage()
        ij.IJ.run(mask_img, "Convert to Mask", "")
        tif_save_cnt = save_tif_with_SN(mask_img, f"measured_mask", dir_metaimg, tif_save_cnt, tif_save_SNdigits, ij)
        mask_img.hide()
        
        rm.runCommand("Show All with labels")
        rm_size = int(rm.getCount())
        if rm_size > 0:
            
            if rm_size == 1:  # success to get fish
                mix_img = imageCalculator.run(crop_img, mask_img, "Average create")
                tif_save_cnt = save_tif_with_SN(mix_img, f"cropped_BF--MIX", subfolder, tif_save_cnt, tif_save_SNdigits, ij)
                
                rm.save(os.path.normpath(f"{dir_metaimg}/RoiSet.zip"))
                ij.IJ.saveAs("Results", os.path.normpath(f"{subfolder}/AutoAnalysis.csv"))
            
            else:
                log.info(f'      ROI in RoiManager: {rm_size}')
                log.info(f'      #### ERROR : Number of ROI not = 1')
                # Write Log
                log_writer.write(f"|         number of ROI = {rm_size} \n")
                log_writer.write("| #### ERROR : Number of ROI not = 1 \n") # ERROR:

            rm.runCommand("Deselect")
            rm.runCommand("Delete") # delete ROI, otherwise, it increases infinitely
            ij.IJ.run("Clear Results", "")
            ij.IJ.run("Close All", "")
            log_writer.write(f"| \n") # make Log file looks better.

# %%
if int(rm.getCount()) > 0:
    rm.runCommand("Deselect")
    rm.runCommand("Delete")
    ij.IJ.run("Clear Results", "")
ij.IJ.run("Close All", "")


analysis_kwargs = {
    "crop_rect" : {"x": 50, "y": 700, "w":1950, "h":700}, # x, y is `Left-Top` pt
    "micron_per_pixel" : 3.25,
    "auto_threshold" : "Triangle",
    "measure_range" : {"lower_bound": 800000, "upper_bound": 4000000} # apply `Set Scale`
}

# File Input
bf_raw_lif_source = r"C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW"

# Result Output
ap_data_root = r"C:\Users\confocal_microscope\Desktop\{PyIJ_OutTest}_BF_Analysis" # r"C:\Users\confocal_microscope\Desktop\WorkingDir\(D2)_Image_AP\{Data}_Data\{20221209_UPDATE_82}_Academia_Sinica_i324"
analysis_method_desc = "KY_with_NameChecker"
analysis_root = os.path.join(ap_data_root, f"{{{analysis_method_desc}}}_BF_Analysis")
create_new_dir(analysis_root, display_in_CLI=False)


# Scan Leica LIF file
lif_path_list  = glob(os.path.normpath(f"{bf_raw_lif_source}/*/*.lif"))
# lif_path_list  = glob(os.path.normpath(f"{bf_raw_lif_source}/*.lif"))
log.info(f'lif_path_list {type(lif_path_list)}: {lif_path_list}, [ found {len(lif_path_list)} files ] \n')


# Create log writer
time_stamp = datetime.now().strftime('%Y%m%d_%H_%M_%S')
log_path = os.path.join(analysis_root, f"{{Logs}}_{{imagej_BF_Analysis}}_{time_stamp}.log")
log_writer = open(log_path, mode="w")
log.info(f'log_writer {type(log_writer)}: {log_writer} \n')


# Write `analysis_kwargs` to log
log_writer.write(f"analysis_kwargs = {json.dumps(analysis_kwargs, indent=4)} \n")


for i, lif_path in enumerate(lif_path_list):
    
    log.info(f"Processing ... {i+1}/{len(lif_path_list)}")
    
    # Write Log
    log_writer.write("\n\n\n")
    log_writer.write(f"|-----------------------------------------  Processing ... {i+1}/{len(lif_path_list)}  ----------------------------------------- \n")
    log_writer.write(f"| \n")
    log_writer.write(f"|         LIF_FILE : {lif_path.split(os.sep)[-1]} \n")
    log_writer.write(f"| \n")

    # analyze current LIF_FILE
    single_BF_Analysis(lif_path, len(lif_path_list), analysis_root, log, log_writer, **analysis_kwargs)
    log.info("\n") # make CLI output looks better.


log.info(" -- finished --")
log_writer.write("\n\n\n-----------------------------------------  finished  ----------------------------------------- \n")
log_writer.close()
# rm.close()
# ij.WindowManager.closeAllWindows()
# Out:
# | 2023-03-03 08:26:25,508 | ImageJ_BF_analysis | INFO | lif_path_list <class 'list'>: ['C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220610 CE001 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220613 CE001 palmskin_11dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220617 CE002 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220620 CE002 palmskin_11dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220621 CE003 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220623 CE003 palmskin_10dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220623 CE004 palmskin_7dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220624 CE004 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220627 CE006 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220628 CE006 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220708 CE009 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220711 CE009 palmskin_11dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220719 CE011 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220725 CE012 palmskin_7dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220727 CE012 palmskin_9dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220816 AI001 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220818 AI001 palmskin_10dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220823 AI002 palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220825 AI002 palmskin_10dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_DL}_Academia_Sinica_Data\\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\\BrightField_RAW\\Before_20221109\\20220830-AI003-palmskin_8dpf.lif', 'C:\\Users\\confocal_microscope\\Desktop\\{NAS_ ...
#
# | 2023-03-03 08:26:25,509 | ImageJ_BF_analysis | INFO | log_writer <class '_io.TextIOWrapper'>: <_io.TextIOWrapper name='C:\\Users\\confocal_microscope\\Desktop\\{PyIJ_OutTest}_BF_Analysis\\{KY_with_NameChecker}_BF_Analysis\\{Logs}_{imagej_BF_Analysis}_20230303_08_26_25.log' mode='w' encoding='UTF-8'>
#
# | 2023-03-03 08:26:25,510 | ImageJ_BF_analysis | INFO | Processing ... 1/25
# | 2023-03-03 08:26:25,534 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220610 CE001 palmskin_8dpf.lif
# | 2023-03-03 08:26:26,030 | ImageJ_BF_analysis | INFO | series 1/6 : '20220610_CE001_palmskin_8dpf - Series001_fish_1_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:26,606 | ImageJ_BF_analysis | INFO | series 2/6 : '20220610_CE001_palmskin_8dpf - Series003_fish_2_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:27,036 | ImageJ_BF_analysis | INFO | series 3/6 : '20220610_CE001_palmskin_8dpf - Series003_fish_3_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:27,434 | ImageJ_BF_analysis | INFO | series 4/6 : '20220610_CE001_palmskin_8dpf - Series004_fish_4_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:27,914 | ImageJ_BF_analysis | INFO | series 5/6 : '20220610_CE001_palmskin_8dpf - Series005_fish_5_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:28,292 | ImageJ_BF_analysis | INFO | series 6/6 : '20220610_CE001_palmskin_8dpf - Series006_fish_6_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:28,476 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:28,476 | ImageJ_BF_analysis | INFO | Processing ... 2/25
# | 2023-03-03 08:26:28,487 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220613 CE001 palmskin_11dpf.lif
# | 2023-03-03 08:26:28,698 | ImageJ_BF_analysis | INFO | series 1/4 : '20220613_CE001_palmskin_11dpf - Series001_fish_7_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:29,103 | ImageJ_BF_analysis | INFO | series 2/4 : '20220613_CE001_palmskin_11dpf - Series002_fish_8_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:29,487 | ImageJ_BF_analysis | INFO | series 3/4 : '20220613_CE001_palmskin_11dpf - Series003_fish_9_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:30,224 | ImageJ_BF_analysis | INFO | series 4/4 : '20220613_CE001_palmskin_11dpf - Series004_fish_10_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:30,402 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:30,403 | ImageJ_BF_analysis | INFO | Processing ... 3/25
# | 2023-03-03 08:26:30,416 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220617 CE002 palmskin_8dpf.lif
# | 2023-03-03 08:26:30,639 | ImageJ_BF_analysis | INFO | series 1/6 : '20220617_CE002_palmskin_8dpf - Series001_fish_11_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:31,145 | ImageJ_BF_analysis | INFO | series 2/6 : '20220617_CE002_palmskin_8dpf - Series002_fish_12_BF' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:31,146 | ImageJ_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-03-03 08:26:32,053 | ImageJ_BF_analysis | INFO | series 3/6 : '20220617_CE002_palmskin_8dpf - Series003_fish_13_BF' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:32,074 | ImageJ_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-03-03 08:26:32,696 | ImageJ_BF_analysis | INFO | series 4/6 : '20220617_CE002_palmskin_8dpf - Series004_fish_14_BF' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:32,697 | ImageJ_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-03-03 08:26:33,351 | ImageJ_BF_analysis | INFO | series 5/6 : '20220617_CE002_palmskin_8dpf - Series005_fish_15_BF' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:33,352 | ImageJ_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-03-03 08:26:34,175 | ImageJ_BF_analysis | INFO | series 6/6 : '20220617_CE002_palmskin_8dpf - Series006_fish_16_BF' , Dimensions : [2048, 2048, 1, 5, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:34,176 | ImageJ_BF_analysis | INFO |       #### WARNING : Number of Slices > 1, run ' Find focused slices '
# | 2023-03-03 08:26:34,493 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:34,494 | ImageJ_BF_analysis | INFO | Processing ... 4/25
# | 2023-03-03 08:26:34,507 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220620 CE002 palmskin_11dpf.lif
# | 2023-03-03 08:26:34,720 | ImageJ_BF_analysis | INFO | series 1/6 : '20220620_CE002_palmskin_11dpf - Series001_fish_17_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:35,101 | ImageJ_BF_analysis | INFO | series 2/6 : '20220620_CE002_palmskin_11dpf - Series002_fish_18_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:35,463 | ImageJ_BF_analysis | INFO | series 3/6 : '20220620_CE002_palmskin_11dpf - Series003_fish_19_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:35,819 | ImageJ_BF_analysis | INFO | series 4/6 : '20220620_CE002_palmskin_11dpf - Series004_fish_20_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:36,171 | ImageJ_BF_analysis | INFO | series 5/6 : '20220620_CE002_palmskin_11dpf - Series005_fish_21_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:36,531 | ImageJ_BF_analysis | INFO | series 6/6 : '20220620_CE002_palmskin_11dpf - Series006_fish_22_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:36,712 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:36,712 | ImageJ_BF_analysis | INFO | Processing ... 5/25
# | 2023-03-03 08:26:36,727 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220621 CE003 palmskin_8dpf.lif
# | 2023-03-03 08:26:36,972 | ImageJ_BF_analysis | INFO | series 1/8 : '20220621_CE003_palmskin_8dpf - Series001_fish_23_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:37,362 | ImageJ_BF_analysis | INFO | series 2/8 : '20220621_CE003_palmskin_8dpf - Series002_fish_24_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:38,063 | ImageJ_BF_analysis | INFO | series 3/8 : '20220621_CE003_palmskin_8dpf - Series003_fish_25_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:38,444 | ImageJ_BF_analysis | INFO | series 4/8 : '20220621_CE003_palmskin_8dpf - Series004_fish_26_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:38,831 | ImageJ_BF_analysis | INFO | series 5/8 : '20220621_CE003_palmskin_8dpf - Series004_fish_27_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:39,235 | ImageJ_BF_analysis | INFO | series 6/8 : '20220621_CE003_palmskin_8dpf - Series005_fish_28_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:39,635 | ImageJ_BF_analysis | INFO | series 7/8 : '20220621_CE003_palmskin_8dpf - Series006_fish_29_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:40,022 | ImageJ_BF_analysis | INFO | series 8/8 : '20220621_CE003_palmskin_8dpf - Series007_fish_30_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:40,185 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:40,186 | ImageJ_BF_analysis | INFO | Processing ... 6/25
# | 2023-03-03 08:26:40,197 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220623 CE003 palmskin_10dpf.lif
# | 2023-03-03 08:26:40,383 | ImageJ_BF_analysis | INFO | series 1/4 : '20220623_CE003_palmskin_10dpf - Series001_fish_31_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2371 micron
# | 2023-03-03 08:26:40,763 | ImageJ_BF_analysis | INFO | series 2/4 : '20220623_CE003_palmskin_10dpf - Series002_fish_32_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2371 micron
# | 2023-03-03 08:26:41,126 | ImageJ_BF_analysis | INFO | series 3/4 : '20220623_CE003_palmskin_10dpf - Series003_fish_33_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:41,494 | ImageJ_BF_analysis | INFO | series 4/4 : '20220623_CE003_palmskin_10dpf - Series004_fish_34_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:41,664 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:41,664 | ImageJ_BF_analysis | INFO | Processing ... 7/25
# | 2023-03-03 08:26:41,675 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220623 CE004 palmskin_7dpf.lif
# | 2023-03-03 08:26:41,879 | ImageJ_BF_analysis | INFO | series 1/8 : '20220623_CE004_palmskin_7dpf - Series001_fish_35_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:42,256 | ImageJ_BF_analysis | INFO | series 2/8 : '20220623_CE004_palmskin_7dpf - Series002_fish_36_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:42,630 | ImageJ_BF_analysis | INFO | series 3/8 : '20220623_CE004_palmskin_7dpf - Series003_fish_37_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:43,234 | ImageJ_BF_analysis | INFO | series 4/8 : '20220623_CE004_palmskin_7dpf - Series004_fish_38_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:43,632 | ImageJ_BF_analysis | INFO | series 5/8 : '20220623_CE004_palmskin_7dpf - Series005_fish_39_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:44,013 | ImageJ_BF_analysis | INFO | series 6/8 : '20220623_CE004_palmskin_7dpf - Series006_fish_40_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:44,382 | ImageJ_BF_analysis | INFO | series 7/8 : '20220623_CE004_palmskin_7dpf - Series007_fish_41_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:44,767 | ImageJ_BF_analysis | INFO | series 8/8 : '20220623_CE004_palmskin_7dpf - Series008_fish_42_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:44,944 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:44,944 | ImageJ_BF_analysis | INFO | Processing ... 8/25
# | 2023-03-03 08:26:44,959 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220624 CE004 palmskin_8dpf.lif
# | 2023-03-03 08:26:45,178 | ImageJ_BF_analysis | INFO | series  1/13 : '20220624_CE004_palmskin_8dpf - Series001_fish_43_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:45,583 | ImageJ_BF_analysis | INFO | series  2/13 : '20220624_CE004_palmskin_8dpf - Series002_fish_44_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:45,969 | ImageJ_BF_analysis | INFO | series  3/13 : '20220624_CE004_palmskin_8dpf - Series003_fish_45_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:46,348 | ImageJ_BF_analysis | INFO | series  4/13 : '20220624_CE004_palmskin_8dpf - Series004_fish_46_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:46,733 | ImageJ_BF_analysis | INFO | series  5/13 : '20220624_CE004_palmskin_8dpf - Series005_fish_47_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:47,131 | ImageJ_BF_analysis | INFO | series  6/13 : '20220624_CE004_palmskin_8dpf - Series006_fish_48_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:47,544 | ImageJ_BF_analysis | INFO | series  7/13 : '20220624_CE004_palmskin_8dpf - Series007_fish_49_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:47,974 | ImageJ_BF_analysis | INFO | series  8/13 : '20220624_CE004_palmskin_8dpf - Series008_fish_50_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:48,542 | ImageJ_BF_analysis | INFO | series  9/13 : '20220624_CE004_palmskin_8dpf - Series009_fish_51_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:48,946 | ImageJ_BF_analysis | INFO | series 10/13 : '20220624_CE004_palmskin_8dpf - Series010_fish_52_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:49,335 | ImageJ_BF_analysis | INFO | series 11/13 : '20220624_CE004_palmskin_8dpf - Series011_fish_53_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:49,742 | ImageJ_BF_analysis | INFO | series 12/13 : '20220624_CE004_palmskin_8dpf - Series012_fish_54_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:50,136 | ImageJ_BF_analysis | INFO | series 13/13 : '20220624_CE004_palmskin_8dpf - Series013_fish_55_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:50,329 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:50,329 | ImageJ_BF_analysis | INFO | Processing ... 9/25
# | 2023-03-03 08:26:50,344 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220627 CE006 palmskin_8dpf.lif
# | 2023-03-03 08:26:50,574 | ImageJ_BF_analysis | INFO | series  1/10 : '20220627_CE006_palmskin_8dpf - Series001_fish_56_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0952 micron
# | 2023-03-03 08:26:50,948 | ImageJ_BF_analysis | INFO | series  2/10 : '20220627_CE006_palmskin_8dpf - Series002_fish_57_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0952 micron
# | 2023-03-03 08:26:51,335 | ImageJ_BF_analysis | INFO | series  3/10 : '20220627_CE006_palmskin_8dpf - Series003_fish_58_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0952 micron
# | 2023-03-03 08:26:51,721 | ImageJ_BF_analysis | INFO | series  4/10 : '20220627_CE006_palmskin_8dpf - Series004_fish_59_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0952 micron
# | 2023-03-03 08:26:52,087 | ImageJ_BF_analysis | INFO | series  5/10 : '20220627_CE006_palmskin_8dpf - Series005_fish_60_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0952 micron
# | 2023-03-03 08:26:52,461 | ImageJ_BF_analysis | INFO | series  6/10 : '20220627_CE006_palmskin_8dpf - Series006_fish_61_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0952 micron
# | 2023-03-03 08:26:52,902 | ImageJ_BF_analysis | INFO | series  7/10 : '20220627_CE006_palmskin_8dpf - Series007_fish_62_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:53,406 | ImageJ_BF_analysis | INFO | series  8/10 : '20220627_CE006_palmskin_8dpf - Series008_fish_63_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:53,773 | ImageJ_BF_analysis | INFO | series  9/10 : '20220627_CE006_palmskin_8dpf - Series009_fish_64_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:54,146 | ImageJ_BF_analysis | INFO | series 10/10 : '20220627_CE006_palmskin_8dpf - Series010_fish_65_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:26:54,317 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:54,318 | ImageJ_BF_analysis | INFO | Processing ... 10/25
# | 2023-03-03 08:26:54,330 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220628 CE006 palmskin_8dpf.lif
# | 2023-03-03 08:26:54,529 | ImageJ_BF_analysis | INFO | series 1/8 : '20220628_CE006_palmskin_8dpf - Series001_fish_66_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:54,920 | ImageJ_BF_analysis | INFO | series 2/8 : '20220628_CE006_palmskin_8dpf - Series002_fish_67_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:55,290 | ImageJ_BF_analysis | INFO | series 3/8 : '20220628_CE006_palmskin_8dpf - Series003_fish_68_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:55,645 | ImageJ_BF_analysis | INFO | series 4/8 : '20220628_CE006_palmskin_8dpf - Series004_fish_69_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:56,021 | ImageJ_BF_analysis | INFO | series 5/8 : '20220628_CE006_palmskin_8dpf - Series005_fish_70_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:56,382 | ImageJ_BF_analysis | INFO | series 6/8 : '20220628_CE006_palmskin_8dpf - Series006_fish_71_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:56,743 | ImageJ_BF_analysis | INFO | series 7/8 : '20220628_CE006_palmskin_8dpf - Series007_fish_72_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:57,131 | ImageJ_BF_analysis | INFO | series 8/8 : '20220628_CE006_palmskin_8dpf - Series008_fish_73_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.0531 micron
# | 2023-03-03 08:26:57,316 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:26:57,317 | ImageJ_BF_analysis | INFO | Processing ... 11/25
# | 2023-03-03 08:26:57,330 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220708 CE009 palmskin_8dpf.lif
# | 2023-03-03 08:26:57,546 | ImageJ_BF_analysis | INFO | series  1/11 : '20220708_CE009_palmskin_8dpf - Series001_fish_74_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:26:57,922 | ImageJ_BF_analysis | INFO | series  2/11 : '20220708_CE009_palmskin_8dpf - Series002_fish_75_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:26:58,005 | ImageJ_BF_analysis | INFO |       ROI in RoiManager: 2
# | 2023-03-03 08:26:58,006 | ImageJ_BF_analysis | INFO |       #### ERROR : Number of ROI not = 1
# | 2023-03-03 08:26:58,282 | ImageJ_BF_analysis | INFO | series  3/11 : '20220708_CE009_palmskin_8dpf - Series003_fish_76_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:26:58,665 | ImageJ_BF_analysis | INFO | series  4/11 : '20220708_CE009_palmskin_8dpf - Series004_fish_77_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:26:59,071 | ImageJ_BF_analysis | INFO | series  5/11 : '20220708_CE009_palmskin_8dpf - Series005_fish_78_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:26:59,524 | ImageJ_BF_analysis | INFO | series  6/11 : '20220708_CE009_palmskin_8dpf - Series006_fish_80_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:26:59,912 | ImageJ_BF_analysis | INFO | series  7/11 : '20220708_CE009_palmskin_8dpf - Series007_fish_81_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:00,288 | ImageJ_BF_analysis | INFO | series  8/11 : '20220708_CE009_palmskin_8dpf - Series009_fish_82_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:00,668 | ImageJ_BF_analysis | INFO | series  9/11 : '20220708_CE009_palmskin_8dpf - Series010_fish_83_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:01,058 | ImageJ_BF_analysis | INFO | series 10/11 : '20220708_CE009_palmskin_8dpf - Series011_fish_84_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:01,427 | ImageJ_BF_analysis | INFO | series 11/11 : '20220708_CE009_palmskin_8dpf - Series012_fish_85_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:01,597 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:01,598 | ImageJ_BF_analysis | INFO | Processing ... 12/25
# | 2023-03-03 08:27:01,607 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220711 CE009 palmskin_11dpf.lif
# | 2023-03-03 08:27:01,788 | ImageJ_BF_analysis | INFO | series 1/5 : '20220711_CE009_palmskin_11dpf - Series001_fish_86_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:02,134 | ImageJ_BF_analysis | INFO | series 2/5 : '20220711_CE009_palmskin_11dpf - Series003_fish_88_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:02,521 | ImageJ_BF_analysis | INFO | series 3/5 : '20220711_CE009_palmskin_11dpf - Series005_fish_90_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:02,872 | ImageJ_BF_analysis | INFO | series 4/5 : '20220711_CE009_palmskin_11dpf - Series006_fish_91_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:03,214 | ImageJ_BF_analysis | INFO | series 5/5 : '20220711_CE009_palmskin_11dpf - Series007_fish_92_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 6.5000 micron
# | 2023-03-03 08:27:03,387 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:03,387 | ImageJ_BF_analysis | INFO | Processing ... 13/25
# | 2023-03-03 08:27:03,397 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220719 CE011 palmskin_8dpf.lif
# | 2023-03-03 08:27:03,588 | ImageJ_BF_analysis | INFO | series 1/8 : '20220719_CE011_palmskin_8dpf - Series001_fish_94_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:03,980 | ImageJ_BF_analysis | INFO | series 2/8 : '20220719_CE011_palmskin_8dpf - Series002_fish_95_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:04,342 | ImageJ_BF_analysis | INFO | series 3/8 : '20220719_CE011_palmskin_8dpf - Series003_fish_96_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:04,701 | ImageJ_BF_analysis | INFO | series 4/8 : '20220719_CE011_palmskin_8dpf - Series004_fish_97_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:05,058 | ImageJ_BF_analysis | INFO | series 5/8 : '20220719_CE011_palmskin_8dpf - Series005_fish_98_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:05,636 | ImageJ_BF_analysis | INFO | series 6/8 : '20220719_CE011_palmskin_8dpf - Series006_fish_99_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:06,001 | ImageJ_BF_analysis | INFO | series 7/8 : '20220719_CE011_palmskin_8dpf - Series007_fish_100_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:06,363 | ImageJ_BF_analysis | INFO | series 8/8 : '20220719_CE011_palmskin_8dpf - Series008_fish_101_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:06,554 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:06,554 | ImageJ_BF_analysis | INFO | Processing ... 14/25
# | 2023-03-03 08:27:06,566 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220725 CE012 palmskin_7dpf.lif
# | 2023-03-03 08:27:06,760 | ImageJ_BF_analysis | INFO | series 1/9 : '20220725_CE012_palmskin_7dpf - Series001_fish_102_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:07,136 | ImageJ_BF_analysis | INFO | series 2/9 : '20220725_CE012_palmskin_7dpf - Series002_fish_103_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:07,516 | ImageJ_BF_analysis | INFO | series 3/9 : '20220725_CE012_palmskin_7dpf - Series003_fish_104_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:07,878 | ImageJ_BF_analysis | INFO | series 4/9 : '20220725_CE012_palmskin_7dpf - Series004_fish_105_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:08,258 | ImageJ_BF_analysis | INFO | series 5/9 : '20220725_CE012_palmskin_7dpf - Series005_fish_106_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:08,625 | ImageJ_BF_analysis | INFO | series 6/9 : '20220725_CE012_palmskin_7dpf - Series006_fish_107_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:08,997 | ImageJ_BF_analysis | INFO | series 7/9 : '20220725_CE012_palmskin_7dpf - Series007_fish_108_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:09,352 | ImageJ_BF_analysis | INFO | series 8/9 : '20220725_CE012_palmskin_7dpf - Series008_fish_109_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:09,710 | ImageJ_BF_analysis | INFO | series 9/9 : '20220725_CE012_palmskin_7dpf - Series009_fish_110_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:09,886 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:09,887 | ImageJ_BF_analysis | INFO | Processing ... 15/25
# | 2023-03-03 08:27:09,897 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220727 CE012 palmskin_9dpf.lif
# | 2023-03-03 08:27:10,100 | ImageJ_BF_analysis | INFO | series 1/7 : '20220727_CE012_palmskin_9dpf - Series001_fish_111_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:10,480 | ImageJ_BF_analysis | INFO | series 2/7 : '20220727_CE012_palmskin_9dpf - Series002_fish_112_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:10,836 | ImageJ_BF_analysis | INFO | series 3/7 : '20220727_CE012_palmskin_9dpf - Series003_fish_113_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:11,216 | ImageJ_BF_analysis | INFO | series 4/7 : '20220727_CE012_palmskin_9dpf - Series004_fish_114_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:11,586 | ImageJ_BF_analysis | INFO | series 5/7 : '20220727_CE012_palmskin_9dpf - Series005_fish_115_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:12,203 | ImageJ_BF_analysis | INFO | series 6/7 : '20220727_CE012_palmskin_9dpf - Series006_fish_116_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:12,562 | ImageJ_BF_analysis | INFO | series 7/7 : '20220727_CE012_palmskin_9dpf - Series007_fish_117_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:12,752 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:12,753 | ImageJ_BF_analysis | INFO | Processing ... 16/25
# | 2023-03-03 08:27:12,759 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220816 AI001 palmskin_8dpf.lif
# | 2023-03-03 08:27:12,922 | ImageJ_BF_analysis | INFO | series 1/1 : '20220816_AI001_palmskin_8dpf - Series001_fish_118_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:13,097 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:13,098 | ImageJ_BF_analysis | INFO | Processing ... 17/25
# | 2023-03-03 08:27:13,103 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220818 AI001 palmskin_10dpf.lif
# | 2023-03-03 08:27:13,269 | ImageJ_BF_analysis | INFO | series 1/1 : '20220818_AI001_palmskin_10dpf - Series001_fish_119_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:13,461 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:13,462 | ImageJ_BF_analysis | INFO | Processing ... 18/25
# | 2023-03-03 08:27:13,471 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220823 AI002 palmskin_8dpf.lif
# | 2023-03-03 08:27:13,657 | ImageJ_BF_analysis | INFO | series 1/5 : '20220823_AI002_palmskin_8dpf - Series001_fish_120_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.7835 micron
# | 2023-03-03 08:27:14,024 | ImageJ_BF_analysis | INFO | series 2/5 : '20220823_AI002_palmskin_8dpf - Series002_fish_121_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.7835 micron
# | 2023-03-03 08:27:14,427 | ImageJ_BF_analysis | INFO | series 3/5 : '20220823_AI002_palmskin_8dpf - Series003_fish_122_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.7835 micron
# | 2023-03-03 08:27:14,782 | ImageJ_BF_analysis | INFO | series 4/5 : '20220823_AI002_palmskin_8dpf - Series004_fish_123_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.7835 micron
# | 2023-03-03 08:27:15,132 | ImageJ_BF_analysis | INFO | series 5/5 : '20220823_AI002_palmskin_8dpf - Series005_fish_124_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.7835 micron
# | 2023-03-03 08:27:15,316 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:15,316 | ImageJ_BF_analysis | INFO | Processing ... 19/25
# | 2023-03-03 08:27:15,328 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220825 AI002 palmskin_10dpf.lif
# | 2023-03-03 08:27:15,545 | ImageJ_BF_analysis | INFO | series  1/10 : '20220825_AI002_palmskin_10dpf - Series001_fish_125_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:15,924 | ImageJ_BF_analysis | INFO | series  2/10 : '20220825_AI002_palmskin_10dpf - Series002_fish_126_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:16,299 | ImageJ_BF_analysis | INFO | series  3/10 : '20220825_AI002_palmskin_10dpf - Series003_fish_127_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:16,676 | ImageJ_BF_analysis | INFO | series  4/10 : '20220825_AI002_palmskin_10dpf - Series004_fish_128_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:17,068 | ImageJ_BF_analysis | INFO | series  5/10 : '20220825_AI002_palmskin_10dpf - Series005_fish_129_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:17,450 | ImageJ_BF_analysis | INFO | series  6/10 : '20220825_AI002_palmskin_10dpf - Series006_fish_130_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:17,836 | ImageJ_BF_analysis | INFO | series  7/10 : '20220825_AI002_palmskin_10dpf - Series007_fish_131_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:18,213 | ImageJ_BF_analysis | INFO | series  8/10 : '20220825_AI002_palmskin_10dpf - Series008_fish_132_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:18,598 | ImageJ_BF_analysis | INFO | series  9/10 : '20220825_AI002_palmskin_10dpf - Series009_fish_133_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:18,970 | ImageJ_BF_analysis | INFO | series 10/10 : '20220825_AI002_palmskin_10dpf - Series010_fish_134_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:19,148 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:19,149 | ImageJ_BF_analysis | INFO | Processing ... 20/25
# | 2023-03-03 08:27:19,274 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220830-AI003-palmskin_8dpf.lif
# | 2023-03-03 08:27:19,527 | ImageJ_BF_analysis | INFO | series 1/7 : '20220830_AI003_palmskin_8dpf - Series001_fish_135_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:19,906 | ImageJ_BF_analysis | INFO | series 2/7 : '20220830_AI003_palmskin_8dpf - Series002_fish_136_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:20,281 | ImageJ_BF_analysis | INFO | series 3/7 : '20220830_AI003_palmskin_8dpf - Series003_fish_137_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:20,647 | ImageJ_BF_analysis | INFO | series 4/7 : '20220830_AI003_palmskin_8dpf - Series004_fish_138_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:21,007 | ImageJ_BF_analysis | INFO | series 5/7 : '20220830_AI003_palmskin_8dpf - Series005_fish_139_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:21,401 | ImageJ_BF_analysis | INFO | series 6/7 : '20220830_AI003_palmskin_8dpf - Series006_fish_140_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:21,795 | ImageJ_BF_analysis | INFO | series 7/7 : '20220830_AI003_palmskin_8dpf - Series007_fish_141_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:21,969 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:21,969 | ImageJ_BF_analysis | INFO | Processing ... 21/25
# | 2023-03-03 08:27:21,983 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20220901-AI003-palmskin_10dpf.lif
# | 2023-03-03 08:27:22,193 | ImageJ_BF_analysis | INFO | series  1/12 : '20220901_AI003_palmskin_10dpf - Series001_fish_142_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:22,584 | ImageJ_BF_analysis | INFO | series  2/12 : '20220901_AI003_palmskin_10dpf - Series002_fish_143_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:22,972 | ImageJ_BF_analysis | INFO | series  3/12 : '20220901_AI003_palmskin_10dpf - Series003_fish_144_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:23,365 | ImageJ_BF_analysis | INFO | series  4/12 : '20220901_AI003_palmskin_10dpf - Series004_fish_145_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:23,744 | ImageJ_BF_analysis | INFO | series  5/12 : '20220901_AI003_palmskin_10dpf - Series005_fish_146_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:24,117 | ImageJ_BF_analysis | INFO | series  6/12 : '20220901_AI003_palmskin_10dpf - Series006_fish_147_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:24,494 | ImageJ_BF_analysis | INFO | series  7/12 : '20220901_AI003_palmskin_10dpf - Series007_fish_148_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:24,891 | ImageJ_BF_analysis | INFO | series  8/12 : '20220901_AI003_palmskin_10dpf - Series008_fish_149_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:25,285 | ImageJ_BF_analysis | INFO | series  9/12 : '20220901_AI003_palmskin_10dpf - Series009_fish_150_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:25,662 | ImageJ_BF_analysis | INFO | series 10/12 : '20220901_AI003_palmskin_10dpf - Series010_fish_151_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:26,056 | ImageJ_BF_analysis | INFO | series 11/12 : '20220901_AI003_palmskin_10dpf - Series011_fish_152_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:26,477 | ImageJ_BF_analysis | INFO | series 12/12 : '20220901_AI003_palmskin_10dpf - Series012_fish_153_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:26,652 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:26,652 | ImageJ_BF_analysis | INFO | Processing ... 22/25
# | 2023-03-03 08:27:26,665 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Before_20221109\20221014-AI004-palmskin_11dpf.lif
# | 2023-03-03 08:27:26,879 | ImageJ_BF_analysis | INFO | series  1/11 : '20221014_AI004_palmskin_11dpf - Series001_fish_154_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:27,251 | ImageJ_BF_analysis | INFO | series  2/11 : '20221014_AI004_palmskin_11dpf - Series002_fish_155_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:27,657 | ImageJ_BF_analysis | INFO | series  3/11 : '20221014_AI004_palmskin_11dpf - Series003_fish_156_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:28,051 | ImageJ_BF_analysis | INFO | series  4/11 : '20221014_AI004_palmskin_11dpf - Series004_fish_157_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:28,449 | ImageJ_BF_analysis | INFO | series  5/11 : '20221014_AI004_palmskin_11dpf - Series005_fish_158_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:28,817 | ImageJ_BF_analysis | INFO | series  6/11 : '20221014_AI004_palmskin_11dpf - Series006_fish_159_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:29,187 | ImageJ_BF_analysis | INFO | series  7/11 : '20221014_AI004_palmskin_11dpf - Series007_fish_160_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:29,561 | ImageJ_BF_analysis | INFO | series  8/11 : '20221014_AI004_palmskin_11dpf - Series008_fish_161_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:29,927 | ImageJ_BF_analysis | INFO | series  9/11 : '20221014_AI004_palmskin_11dpf - Series009_fish_162_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:30,317 | ImageJ_BF_analysis | INFO | series 10/11 : '20221014_AI004_palmskin_11dpf - Series010_fish_163_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:30,692 | ImageJ_BF_analysis | INFO | series 11/11 : '20221014_AI004_palmskin_11dpf - Series011_fish_164_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:30,877 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:30,877 | ImageJ_BF_analysis | INFO | Processing ... 23/25
# | 2023-03-03 08:27:30,895 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Upload_20221209\20221125_AI005_palmskin_10dpf.lif
# | 2023-03-03 08:27:31,140 | ImageJ_BF_analysis | INFO | series  1/21 : '20221125_AI005_palmskin_10dpf - Series001_fish_165_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:31,551 | ImageJ_BF_analysis | INFO | series  2/21 : '20221125_AI005_palmskin_10dpf - Series002_fish_166_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:32,002 | ImageJ_BF_analysis | INFO | series  3/21 : '20221125_AI005_palmskin_10dpf - Series003_fish_167_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:32,422 | ImageJ_BF_analysis | INFO | series  4/21 : '20221125_AI005_palmskin_10dpf - Series004_fish_168_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:32,839 | ImageJ_BF_analysis | INFO | series  5/21 : '20221125_AI005_palmskin_10dpf - Series005_fish_169_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:33,389 | ImageJ_BF_analysis | INFO | series  6/21 : '20221125_AI005_palmskin_10dpf - Series006_fish_170_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:33,802 | ImageJ_BF_analysis | INFO | series  7/21 : '20221125_AI005_palmskin_10dpf - Series007_fish_171_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:34,216 | ImageJ_BF_analysis | INFO | series  8/21 : '20221125_AI005_palmskin_10dpf - Series008_fish_172_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:34,620 | ImageJ_BF_analysis | INFO | series  9/21 : '20221125_AI005_palmskin_10dpf - Series009_fish_173_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:35,114 | ImageJ_BF_analysis | INFO | series 10/21 : '20221125_AI005_palmskin_10dpf - Series010_fish_174_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:35,536 | ImageJ_BF_analysis | INFO | series 11/21 : '20221125_AI005_palmskin_10dpf - Series011_fish_175_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:35,972 | ImageJ_BF_analysis | INFO | series 12/21 : '20221125_AI005_palmskin_10dpf - Series012_fish_176_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:36,374 | ImageJ_BF_analysis | INFO | series 13/21 : '20221125_AI005_palmskin_10dpf - Series013_fish_177_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:36,801 | ImageJ_BF_analysis | INFO | series 14/21 : '20221125_AI005_palmskin_10dpf - Series014_fish_178_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:37,217 | ImageJ_BF_analysis | INFO | series 15/21 : '20221125_AI005_palmskin_10dpf - Series015_fish_179_BF_delete' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:37,218 | ImageJ_BF_analysis | INFO |       #### CRITICAL ERROR --> len(image_name_list) = '5', expect '4'
# | 2023-03-03 08:27:37,669 | ImageJ_BF_analysis | INFO | series 16/21 : '20221125_AI005_palmskin_10dpf - Series016_fish_180_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:38,096 | ImageJ_BF_analysis | INFO | series 17/21 : '20221125_AI005_palmskin_10dpf - Series017_fish_181_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:38,512 | ImageJ_BF_analysis | INFO | series 18/21 : '20221125_AI005_palmskin_10dpf - Series018_fish_182_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:38,918 | ImageJ_BF_analysis | INFO | series 19/21 : '20221125_AI005_palmskin_10dpf - Series019_fish_183_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:39,356 | ImageJ_BF_analysis | INFO | series 20/21 : '20221125_AI005_palmskin_10dpf - Series020_fish_184_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:39,919 | ImageJ_BF_analysis | INFO | series 21/21 : '20221125_AI005_palmskin_10dpf - Series021_fish_186_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:40,084 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:40,085 | ImageJ_BF_analysis | INFO | Processing ... 24/25
# | 2023-03-03 08:27:40,106 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Upload_20221209\20221126_AI005_palmskin_11dpf.lif
# | 2023-03-03 08:27:40,375 | ImageJ_BF_analysis | INFO | series  1/16 : '20221126_AI005_palmskin_11dpf - Series001_fish_187_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:40,794 | ImageJ_BF_analysis | INFO | series  2/16 : '20221126_AI005_palmskin_11dpf - Series002_fish_188_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:41,183 | ImageJ_BF_analysis | INFO | series  3/16 : '20221126_AI005_palmskin_11dpf - Series003_fish_189_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:41,573 | ImageJ_BF_analysis | INFO | series  4/16 : '20221126_AI005_palmskin_11dpf - Series004_fish_190_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:41,968 | ImageJ_BF_analysis | INFO | series  5/16 : '20221126_AI005_palmskin_11dpf - Series005_fish_191_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:42,349 | ImageJ_BF_analysis | INFO | series  6/16 : '20221126_AI005_palmskin_11dpf - Series006_fish_192_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:42,742 | ImageJ_BF_analysis | INFO | series  7/16 : '20221126_AI005_palmskin_11dpf - Series007_fish_193_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:43,126 | ImageJ_BF_analysis | INFO | series  8/16 : '20221126_AI005_palmskin_11dpf - Series008_fish_194_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:43,558 | ImageJ_BF_analysis | INFO | series  9/16 : '20221126_AI005_palmskin_11dpf - Series009_fish_195_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:43,991 | ImageJ_BF_analysis | INFO | series 10/16 : '20221126_AI005_palmskin_11dpf - Series010_fish_196_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:44,400 | ImageJ_BF_analysis | INFO | series 11/16 : '20221126_AI005_palmskin_11dpf - Series011_fish_197_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:44,796 | ImageJ_BF_analysis | INFO | series 12/16 : '20221126_AI005_palmskin_11dpf - Series012_fish_198_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:45,193 | ImageJ_BF_analysis | INFO | series 13/16 : '20221126_AI005_palmskin_11dpf - Series013_fish_199_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:45,583 | ImageJ_BF_analysis | INFO | series 14/16 : '20221126_AI005_palmskin_11dpf - Series014_fish_200_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:45,973 | ImageJ_BF_analysis | INFO | series 15/16 : '20221126_AI005_palmskin_11dpf - Series015_fish_201_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:46,379 | ImageJ_BF_analysis | INFO | series 16/16 : '20221126_AI005_palmskin_11dpf - Series016_fish_202_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:46,559 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:46,559 | ImageJ_BF_analysis | INFO | Processing ... 25/25
# | 2023-03-03 08:27:46,568 | ImageJ_BF_analysis | INFO | LIF_FILE : C:\Users\confocal_microscope\Desktop\{NAS_DL}_Academia_Sinica_Data\{20230213_DirNameAdjust}_Zebrafish_A_P_strategies\BrightField_RAW\Upload_20221209\20221127_AI005_palmskin_12dpf.lif
# | 2023-03-03 08:27:46,935 | ImageJ_BF_analysis | INFO | series 1/5 : '20221127_AI005_palmskin_12dpf - Series001_fish_203_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:47,296 | ImageJ_BF_analysis | INFO | series 2/5 : '20221127_AI005_palmskin_12dpf - Series002_fish_204_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:47,651 | ImageJ_BF_analysis | INFO | series 3/5 : '20221127_AI005_palmskin_12dpf - Series003_fish_205_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:48,030 | ImageJ_BF_analysis | INFO | series 4/5 : '20221127_AI005_palmskin_12dpf - Series004_fish_206_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:48,391 | ImageJ_BF_analysis | INFO | series 5/5 : '20221127_AI005_palmskin_12dpf - Series005_fish_207_BF' , Dimensions : [2048, 2048, 1, 1, 1] ( width, height, channels, slices, frames ), Voxel_X_Y : 3.2500 micron
# | 2023-03-03 08:27:48,569 | ImageJ_BF_analysis | INFO |
#
# | 2023-03-03 08:27:48,570 | ImageJ_BF_analysis | INFO |  -- finished --

# %%
log_writer.close()

# %% [markdown]
# # Other Useful Methods
#
# ```
# ij.WindowManager.closeAllWindows()
#
# ij.WindowManager.getCurrentImage()
#
# img.getProperties()
#
# ij.WindowManager.getActiveWindow()
# ```
